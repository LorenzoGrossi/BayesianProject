# %%
from cmdstanpy import cmdstan_path, CmdStanModel

import arviz as az
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions

# %%
import cmdstanpy
cmdstanpy.install_cmdstan()
a=cmdstan_path()
# Out:
# Installing CmdStan version: 2.31.0
# Install directory: /root/.cmdstan
# Downloading CmdStan version 2.31.0
# Download successful, file: /tmp/tmpvhez8zxf
# Extracting distribution
# DEBUG:cmdstanpy:cmd: make build -j1
# cwd: None
# Unpacked download as cmdstan-2.31.0
# Building version cmdstan-2.31.0, may take several minutes, depending on your system.
# DEBUG:cmdstanpy:cmd: make examples/bernoulli/bernoulli
# cwd: None
# Test model compilation
# Installed cmdstan-2.31.0

# %%
# Importing 2018-19 season results
Xall=pd.read_csv("season-1819_csv.csv")
cols = Xall.columns
X=Xall[['Date','HomeTeam','AwayTeam','FTR']]
X.head()
# Out:
#          Date HomeTeam  AwayTeam FTR
# 0  18/08/2018   Chievo  Juventus   A
# 1  18/08/2018    Lazio    Napoli   A
# 2  19/08/2018  Bologna      Spal   A
# 3  19/08/2018   Empoli  Cagliari   H
# 4  19/08/2018    Parma   Udinese   D

# %%
# Importing 2017-18 season results
Xall=pd.read_csv("season-1718_csv.csv")
cols = Xall.columns
X_old=Xall[['Date','HomeTeam','AwayTeam','FTR']]
X_old.head()
# Out:
#        Date  HomeTeam  AwayTeam FTR
# 0  19/08/17  Juventus  Cagliari   H
# 1  19/08/17    Verona    Napoli   A
# 2  20/08/17  Atalanta      Roma   A
# 3  20/08/17   Bologna    Torino   D
# 4  20/08/17   Crotone     Milan   A

# %% [markdown]
# ###Controllo le squadre che scendono in B e quelle che salgono in A
#
# Scendono: Benevento, Crotone, Verona
#
#
# Salgono: Empoli, Frosinone,Parma

# %%
Teams_old=list(X_old.iloc[:,1].unique())
Teams_old=sorted(Teams_old)
Teams_old
# Out:
# ['Atalanta',
#  'Benevento',
#  'Bologna',
#  'Cagliari',
#  'Chievo',
#  'Crotone',
#  'Fiorentina',
#  'Genoa',
#  'Inter',
#  'Juventus',
#  'Lazio',
#  'Milan',
#  'Napoli',
#  'Roma',
#  'Sampdoria',
#  'Sassuolo',
#  'Spal',
#  'Torino',
#  'Udinese',
#  'Verona']

# %%
Teams=list(X.iloc[:,1].unique())
Teams=sorted(Teams)
Teams #Salgono in serie A frosinone parma empoli
# Out:
# ['Atalanta',
#  'Bologna',
#  'Cagliari',
#  'Chievo',
#  'Empoli',
#  'Fiorentina',
#  'Frosinone',
#  'Genoa',
#  'Inter',
#  'Juventus',
#  'Lazio',
#  'Milan',
#  'Napoli',
#  'Parma',
#  'Roma',
#  'Sampdoria',
#  'Sassuolo',
#  'Spal',
#  'Torino',
#  'Udinese']

# %%
X_old.loc[X_old.HomeTeam == 'Benevento', 'HomeTeam'] = 'Frosinone'
X_old.loc[X_old.AwayTeam == 'Benevento', 'AwayTeam'] = 'Frosinone'

X_old.loc[X_old.HomeTeam == 'Crotone', 'HomeTeam'] = 'Empoli'
X_old.loc[X_old.AwayTeam == 'Crotone', 'AwayTeam'] = 'Empoli'

X_old.loc[X_old.HomeTeam == "Verona", 'HomeTeam'] = 'Parma'
X_old.loc[X_old.AwayTeam == "Verona", 'AwayTeam'] = 'Parma'

Teams_old=list(X_old.iloc[:,1].unique())
Teams_old=sorted(Teams_old)
pd.options.mode.chained_assignment = None  # default='warn'
# Out:
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /usr/local/lib/python3.8/dist-packages/pandas/core/indexing.py:723: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   iloc._setitem_with_indexer(indexer, value, self.name)

# %%
Teams_old==Teams
# Out:
# True

# %%
Y = np.array([2 if(X.iloc[i,3]=='H') else(0 if(X.iloc[i,3]=='A') else(1)) for i in range(X.shape[0])])

X['Y']=Y.tolist()
X.head()
# Out:
#          Date HomeTeam  AwayTeam FTR  Y
# 0  18/08/2018   Chievo  Juventus   A  0
# 1  18/08/2018    Lazio    Napoli   A  0
# 2  19/08/2018  Bologna      Spal   A  0
# 3  19/08/2018   Empoli  Cagliari   H  2
# 4  19/08/2018    Parma   Udinese   D  1

# %%
plt.hist(Y)
# Out:
# (array([106.,   0.,   0.,   0.,   0., 108.,   0.,   0.,   0., 166.]),
#  array([0. , 0.2, 0.4, 0.6, 0.8, 1. , 1.2, 1.4, 1.6, 1.8, 2. ]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# ### Matrix and old skill computation

# %%
# Versione 2.0 
def names_to_index(Teams):

    """
    Creates a dictionary that associates teams to number
    """
    # dictionary comprehension
    d = {index: value for value, index in enumerate(Teams)}

    return d

# %%
def crea_matrici(X):
    """
    Takes as input a matrix X and their result to create two additional matrices that can be used for our model
    """
    #matrice casa trasferta risultato in numeri (N_match, 3)
    Y = np.array([3 if(X.iloc[i,3]=='H') else(0 if(X.iloc[i,3]=='A') else(1)) for i in range(X.shape[0])])
    
    Teams=list(X.iloc[:,1].unique())
    Teams=sorted(Teams)
    d = names_to_index(Teams)
    
    T_1 = np.array([d[X.iloc[i,1]] for i in range(X.shape[0])])
    T_2 = np.array([d[X.iloc[i,2]] for i in range(X.shape[0])])
    R = pd.DataFrame({"Home":T_1,"Away":T_2,"Result":Y})
    
    #matrice di storie delle squadre, casa-trasferta (N_Teams, 2)
    dim_vec_home = R['Home'].value_counts()
    dim_vec_away = R['Away'].value_counts()
    
    R2 = pd.DataFrame(index = sorted(np.unique(T_1)), columns = ["Home", "Away"])
    
    for i in range(len(np.unique(T_1))):
        R2["Home"][i] = np.empty(0,dtype = np.int8)
        R2["Away"][i] = np.empty(0,dtype = np.int8)
        
    for i in range(len(T_1)):
        h = R["Home"][i]
        a = R["Away"][i]
        R2["Home"][h] = np.append(R2["Home"][h],R["Result"][i])
        if(R["Result"][i]==1):                                      #Caso pareggi 1 punto
          R2["Away"][a] = np.append(R2["Away"][a], R["Result"][i])
        else:                                                       #Sconfitta 0 punti
          R2["Away"][a] = np.append(R2["Away"][a], 3 - R["Result"][i])
        
    
    
    return R,R2

# %%
def compute_skills(R,R2,init_home,init_away):
    """
    Takes as inputs a matrix X with teams and their result
    init is the inizialization of the skills, must be an array or list with the skill for each team.

    Returns two matrices with home and away skills parameters by team 
    and one matrix with skills parameters oredered cronologically
    """
    import numpy as np
    import pandas as pd

    N=R.shape[0] # number of matches
    
    #Lambda initialization
    l1 = 0.2
    l2 = 0.2

    #Creating matrices to store the skill parameters and their stories
        
    HS = pd.DataFrame(index = R2.index, columns = ["Home", "Away"])
    
    for i in range(R2.shape[0]):
        HS["Home"][i] = np.empty(0)
        HS["Away"][i] = np.empty(0)
        
    data = pd.DataFrame(index = R.index, columns=['Home','Away'])
    C = pd.DataFrame({"Home": np.zeros(len(R2.index), dtype = np.int8), "Away": np.zeros(len(R2.index), dtype = np.int8)})
    
    for i in range(R.shape[0]):
        h = R["Home"][i]
        a = R["Away"][i]
        #calcolo somma per xh
        sh = 0
        for j in range(C["Home"][h]):
            sh = sh + R2["Home"][h][j]*(1-l1)**j
        
        xh = l1*sh + init_home[h]*(1-l1)**C["Home"][h]
        
        #calcolo somma per xv
        sa = 0
        for j in range(C["Away"][a]):
            sa = sa + R2["Away"][a][j]*(1-l2)**j
        
        xv = l2*sa + init_away[a]*(1-l2)**C["Away"][a]
        
        #append nostra matrice storico e dati per stan
        HS["Home"][h] = np.append(HS["Home"][h],round(xh,3))
        HS["Away"][a] = np.append(HS["Away"][a],round(xv,3))
        data["Home"][i] = round(xh,3)
        data["Away"][i] = round(xv,3)
        
        #incremento counts
        C["Home"][h] += 1
        C["Away"][a] += 1

    
    return HS,data

# %%
R_old, R2_old = crea_matrici(X)
HS_old, data_old = compute_skills(R_old, R2_old, 0.5*np.ones(len(Teams)), 0.5*np.ones(len(Teams)))

plt.plot(HS_old["Home"][0])

# %%
init_home = np.empty(0)
init_away = np.empty(0)

for i in range(HS_old.shape[0]):
  init_home = np.append(init_home,HS_old["Home"][i][-1])
  init_away = np.append(init_away,HS_old["Away"][i][-1])

R,R2 = crea_matrici(X)

# %% [markdown]
# ## Final model

# %%
ordinal_reg = '''
data{
    int<lower=0> N; // Matches
    array[N] int y;
    int<lower=0> T; // Teams
    array[N,3] int R;  // Game+Result matrix
    array[T,2,19] int R2; // Teams' history
    vector[T] IH;    // init_home
    vector[T] IA;    // init_away
}

parameters { vector[2] beta; // coefficients for predictor variables 
            real intercept1;
            real<lower=intercept1+0.0001,upper=100000> intercept2;
            real<lower=0,upper=1> l1;
            real<lower=0,upper=1> l2;
}

transformed parameters {
  matrix[N,2] X;     // Skills
  real sh;
  real sa;
  vector[N] mu;
  vector[2] intercept;
  intercept[1] = intercept1;
  intercept[2] = intercept2;
  {
  array[T,2] int C=rep_array(0,T,2);

  for(i in 1:N){
    int h = R[i,1]+1; // Home team index
    int a = R[i,2]+1; // Away team index
    int ch = C[h,1]; // Home count
    int ca = C[a,2]; //Away count

    // Home team skill update
    if(ch==0){
      X[i,1] = IH[h];
    }
    else{
      sh=0;
      for(j in 1:ch){   
        sh=sh+R2[h,1,j]*pow((1-l1),j);
        }
      X[i,1]=l1*sh+IH[h]*pow((1-l1),ch);
    }

    // Away team skill update
    if(ca==0){
      X[i,2] = IA[a];
    }
    else{
      sa=0;
      for(j in 1:ca){   
        sa=sa+R2[a,2,j]*pow((1-l2),j);
      }
      X[i,2]=l2*sa+IA[a]*pow((1-l2),ca);
    }

    // Count update
    C[h,1]=C[h,1]+1;
    C[a,2]=C[a,2]+1;

    mu[i] = row(X, i) * beta;
  }

  }
}

model { // calculate likelihood of ordinal categories given predictor variable values and coefficients 
       
       beta[1] ~ normal(1.2,2);
       beta[2] ~ normal(-1.3,2);  
  
       intercept1 ~ normal(-0.6,2);
       intercept2 ~ normal(0.8,2);

       l1 ~ beta(2,5);
       l1 ~ beta(1,3);

       for (i in 1:N) { 
         y[i] ~ ordered_logistic(mu[i],intercept); } 
       }

generated quantities{
  vector[N] y_pred; 
  for(i in 1:N){
    y_pred[i] = ordered_logistic_rng(mu[i],intercept);
  }
}
'''

stan_file = "./ordinal_reg.stan"

with open(stan_file, "w") as f:
    print(ordinal_reg, file=f)

ordinal_reg = CmdStanModel(stan_file=stan_file)
# Out:
# 20:25:31 - cmdstanpy - INFO - compiling stan file /content/ordinal_reg.stan to exe file /content/ordinal_reg
# INFO:cmdstanpy:compiling stan file /content/ordinal_reg.stan to exe file /content/ordinal_reg
# DEBUG:cmdstanpy:cmd: make /content/ordinal_reg
# cwd: /root/.cmdstan/cmdstan-2.31.0
# DEBUG:cmdstanpy:Console output:
#
# --- Translating Stan model to C++ code ---
# bin/stanc  --o=/content/ordinal_reg.hpp /content/ordinal_reg.stan
#
# --- Compiling, linking C++ code ---
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I stan/lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.78.0 -I stan/lib/stan_math/lib/sundials_6.1.1/include -I stan/lib/stan_math/lib/sundials_6.1.1/src/sundials    -DBOOST_DISABLE_ASSERTS          -c -Wno-ignored-attributes   -x c++ -o /content/ordinal_reg.o /content/ordinal_reg.hpp
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I stan/lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.78.0 -I stan/lib/stan_math/lib/sundials_6.1.1/include -I stan/lib/stan_math/lib/sundials_6.1.1/src/sundials    -DBOOST_DISABLE_ASSERTS                -Wl,-L,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb"      /content/ordinal_reg.o src/cmdstan/main.o        -Wl,-L,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb"   stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_cvodes.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_idas.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_kinsol.a  stan/lib/stan_math/lib/tbb/libtbb.so.2 -o /content/ordinal_reg
# rm -f /content/ordinal_reg.o
#
# 20:25:50 - cmdstanpy - INFO - compiled model executable: /content/ordinal_reg
# INFO:cmdstanpy:compiled model executable: /content/ordinal_reg

# %%
model_data = {'N': len(Y), 'y': Y+1, 'T': len(Teams), 'R': R, 'R2': R2.values.tolist(), 'IH': init_home, 'IA': init_away}

model_fit=ordinal_reg.sample(data=model_data, chains=4,
                           parallel_chains=4, iter_warmup=1000,
                           iter_sampling=5000)
model_data=az.from_cmdstanpy(model_fit)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpuvoizeri/tq3e3dj2.json
# DEBUG:cmdstanpy:cmd: /content/ordinal_reg info
# cwd: None
# 20:25:50 - cmdstanpy - INFO - CmdStan start processing
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=1', 'random', 'seed=65747', 'data', 'file=/tmp/tmpuvoizeri/tq3e3dj2.json', 'output', 'file=/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_1.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'adapt', 'engaged=1']
# DEBUG:cmdstanpy:idx 1
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=2', 'random', 'seed=65747', 'data', 'file=/tmp/tmpuvoizeri/tq3e3dj2.json', 'output', 'file=/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_2.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'adapt', 'engaged=1']
# DEBUG:cmdstanpy:idx 2
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=3', 'random', 'seed=65747', 'data', 'file=/tmp/tmpuvoizeri/tq3e3dj2.json', 'output', 'file=/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_3.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'adapt', 'engaged=1']
# DEBUG:cmdstanpy:idx 3
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=4', 'random', 'seed=65747', 'data', 'file=/tmp/tmpuvoizeri/tq3e3dj2.json', 'output', 'file=/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_4.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'adapt', 'engaged=1']
# 20:32:04 - cmdstanpy - INFO - CmdStan done processing.
# INFO:cmdstanpy:CmdStan done processing.
# DEBUG:cmdstanpy:runset
# RunSet: chains=4, chain_ids=[1, 2, 3, 4], num_processes=4
#  cmd (chain 1):
# 	['/content/ordinal_reg', 'id=1', 'random', 'seed=65747', 'data', 'file=/tmp/tmpuvoizeri/tq3e3dj2.json', 'output', 'file=/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_1.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'adapt', 'engaged=1']
#  retcodes=[0, 0, 0, 0]
#  per-chain output files (showing chain 1 only):
#  csv_file:
# 	/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_1.csv
#  console_msgs (if any):
# 	/tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_0-stdout.txt
# DEBUG:cmdstanpy:Chain 1 console:
# method = sample (Default)
#   sample
#     num_samples = 5000
#     num_warmup = 1000 (Default)
#     save_warmup = 0 (Default)
#     thin = 1 (Default)
#     adapt
#       engaged = 1 (Default)
#       gamma = 0.050000000000000003 (Default)
#       delta = 0.80000000000000004 (Default)
#       kappa = 0.75 (Default)
#       t0 = 10 (Default)
#       init_buffer = 75 (Default)
#       term_buffer = 50 (Default)
#       window = 25 (Default)
#     algorithm = hmc (Default)
#       hmc
#         engine = nuts (Default)
#           nuts
#             max_depth = 10 (Default)
#         metric = diag_e (Default)
#         metric_file =  (Default)
#         stepsize = 1 (Default)
#         stepsize_jitter = 0 (Default)
#     num_chains = 1 (Default)
# id = 1 (Default)
# data
#   file = /tmp/tmpuvoizeri/tq3e3dj2.json
# init = 2 (Default)
# random
#   seed = 65747
# output
#   file = /tmp/tmpuvoizeri/ordinal_reg0zxtf0gc/ordinal_reg-20230127202550_1.csv
#   diagnostic_file =  (Default)
#   refresh = 100 (Default)
#   sig_figs = -1 (Default)
#   profile_file = profile.csv (Default)
# num_threads = 1 (Default)
#
#
# Gradient evaluation took 0.011632 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 116.32 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:    1 / 6000 [  0%]  (Warmup)
# Iteration:  100 / 6000 [  1%]  (Warmup)
# Iteration:  200 / 6000 [  3%]  (Warmup)
# Iteration:  300 / 6000 [  5%]  (Warmup)
# Iteration:  400 / 6000 [  6%]  (Warmup)
# Iteration:  500 / 6000 [  8%]  (Warmup)
# Iteration:  600 / 6000 [ 10%]  (Warmup)
# Iteration:  700 / 6000 [ 11%]  (Warmup)
# Iteration:  800 / 6000 [ 13%]  (Warmup)
# Iteration:  900 / 6000 [ 15%]  (Warmup)
# Iteration: 1000 / 6000 [ 16%]  (Warmup)
# Iteration: 1001 / 6000 [ 16%]  (Sampling)
# Iteration: 1100 / 6000 [ 18%]  (Sampling)
# Iteration: 1200 / 6000 [ 20%]  (Sampling)
# Iteration: 1300 / 6000 [ 21%]  (Sampling)
# Iteration: 1400 / 6000 [ 23%]  (Sampling)
# Iteration: 1500 / 6000 [ 25%]  (Sampling)
# Iteration: 1600 / 6000 [ 26%]  (Sampling)
# Iteration: 1700 / 6000 [ 28%]  (Sampling)
# Iteration: 1800 / 6000 [ 30%]  (Sampling)
# Iteration: 1900 / 6000 [ 31%]  (Sampling)
# Iteration: 2000 / 6000 [ 33%]  (Sampling)
# Iteration: 2100 / 6000 [ 35%]  (Sampling)
# Iteration: 2200 / 6000 [ 36%]  (Sampling)
# Iteration: 2300 / 6000 [ 38%]  (Sampling)
# Iteration: 2400 / 6000 [ 40%]  (Sampling)
# Iteration: 2500 / 6000 [ 41%]  (Sampling)
# Iteration: 2600 / 6000 [ 43%]  (Sampling)
# Iteration: 2700 / 6000 [ 45%]  (Sampling)
# Iteration: 2800 / 6000 [ 46%]  (Sampling)
# Iteration: 2900 / 6000 [ 48%]  (Sampling)
# Iteration: 3000 / 6000 [ 50%]  (Sampling)
# Iteration: 3100 / 6000 [ 51%]  (Sampling)
# Iteration: 3200 / 6000 [ 53%]  (Sampling)
# Iteration: 3300 / 6000 [ 55%]  (Sampling)
# Iteration: 3400 / 6000 [ 56%]  (Sampling)
# Iteration: 3500 / 6000 [ 58%]  (Sampling)
# Iteration: 3600 / 6000 [ 60%]  (Sampling)
# Iteration: 3700 / 6000 [ 61%]  (Sampling)
# Iteration: 3800 / 6000 [ 63%]  (Sampling)
# Iteration: 3900 / 6000 [ 65%]  (Sampling)
# Iteration: 4000 / 6000 [ 66%]  (Sampling)
# Iteration: 4100 / 6000 [ 68%]  (Sampling)
# Iteration: 4200 / 6000 [ 70%]  (Sampling)
# Iteration: 4300 / 6000 [ 71%]  (Sampling)
# Iteration: 4400 / 6000 [ 73%]  (Sampling)
# Iteration: 4500 / 6000 [ 75%]  (Sampling)
# Iteration: 4600 / 6000 [ 76%]  (Sampling)
# Iteration: 4700 / 6000 [ 78%]  (Sampling)
# Iteration: 4800 / 6000 [ 80%]  (Sampling)
# Iteration: 4900 / 6000 [ 81%]  (Sampling)
# Iteration: 5000 / 6000 [ 83%]  (Sampling)
# Iteration: 5100 / 6000 [ 85%]  (Sampling)
# Iteration: 5200 / 6000 [ 86%]  (Sampling)
# Iteration: 5300 / 6000 [ 88%]  (Sampling)
# Iteration: 5400 / 6000 [ 90%]  (Sampling)
# Iteration: 5500 / 6000 [ 91%]  (Sampling)
# Iteration: 5600 / 6000 [ 93%]  (Sampling)
# Iteration: 5700 / 6000 [ 95%]  (Sampling)
# Iteration: 5800 / 6000 [ 96%]  (Sampling)
# Iteration: 5900 / 6000 [ 98%]  (Sampling)
# Iteration: 6000 / 6000 [100%]  (Sampling)
#
#  Elapsed Time: 57.029 seconds (Warm-up)
#                316.029 seconds (Sampling)
#                373.058 seconds (Total)

# %%
cmdstanpy_data = az.from_cmdstanpy(model_fit)
np.sum(cmdstanpy_data.sample_stats.diverging)
# Out:
# <xarray.DataArray 'diverging' ()>
# array(0)

# %%
az.plot_trace(model_data, var_names=["intercept","beta","l1","l2"], compact=False)
plt.tight_layout()
#plt.savefig('ParamMod')
plt.show()

# %%
model_fit.X[1]
# Out:
# (380, 2)

# %%
pred2 = model_fit.y_pred
m2=0
for i in range(pred2.shape[0]):
  if m2 < sum(pred2[i] == Y+1):
    m2 = sum(pred2[i] == Y+1)
    idx2 = i

# %%
print(m2,idx2)
# Out:
# 198 6145

# %%
for i in range(pred2.shape[1]):
  unique, counts = np.unique(pred2[:,i], return_counts=True)
  perc = counts/pred2.shape[0]*100
  print("Valore predetto: 0 al ",round(perc[0],2),"% mentre 1 al ",round(perc[1],2),"% mentre 2 al ",round(perc[2],2),"%. Valore vero: ", Y[i], "indice: ",i)
# Out:
# Valore predetto: 0 al  92.2 % mentre 1 al  5.87 % mentre 2 al  1.93 %. Valore vero:  0 indice:  0
# Valore predetto: 0 al  43.29 % mentre 1 al  33.3 % mentre 2 al  23.42 %. Valore vero:  0 indice:  1
# Valore predetto: 0 al  36.32 % mentre 1 al  34.42 % mentre 2 al  29.26 %. Valore vero:  0 indice:  2
# Valore predetto: 0 al  21.23 % mentre 1 al  31.96 % mentre 2 al  46.8 %. Valore vero:  2 indice:  3
# Valore predetto: 0 al  25.58 % mentre 1 al  33.58 % mentre 2 al  40.84 %. Valore vero:  1 indice:  4
# Valore predetto: 0 al  34.84 % mentre 1 al  34.19 % mentre 2 al  30.96 %. Valore vero:  2 indice:  5
# Valore predetto: 0 al  34.89 % mentre 1 al  34.44 % mentre 2 al  30.67 %. Valore vero:  0 indice:  6
# Valore predetto: 0 al  14.4 % mentre 1 al  27.38 % mentre 2 al  58.21 %. Valore vero:  2 indice:  7
# Valore predetto: 0 al  11.72 % mentre 1 al  24.63 % mentre 2 al  63.64 %. Valore vero:  2 indice:  8
# Valore predetto: 0 al  9.75 % mentre 1 al  21.39 % mentre 2 al  68.86 %. Valore vero:  2 indice:  9
# Valore predetto: 0 al  27.33 % mentre 1 al  34.29 % mentre 2 al  38.38 %. Valore vero:  1 indice:  10
# Valore predetto: 0 al  6.32 % mentre 1 al  15.59 % mentre 2 al  78.09 %. Valore vero:  2 indice:  11
# Valore predetto: 0 al  37.79 % mentre 1 al  33.75 % mentre 2 al  28.47 %. Valore vero:  1 indice:  12
# Valore predetto: 0 al  8.8 % mentre 1 al  19.55 % mentre 2 al  71.65 %. Valore vero:  2 indice:  13
# Valore predetto: 0 al  23.89 % mentre 1 al  33.64 % mentre 2 al  42.47 %. Valore vero:  1 indice:  14
# Valore predetto: 0 al  32.71 % mentre 1 al  34.56 % mentre 2 al  32.73 %. Valore vero:  2 indice:  15
# Valore predetto: 0 al  38.1 % mentre 1 al  34.11 % mentre 2 al  27.78 %. Valore vero:  2 indice:  16
# Valore predetto: 0 al  22.46 % mentre 1 al  33.77 % mentre 2 al  43.76 %. Valore vero:  1 indice:  17
# Valore predetto: 0 al  19.59 % mentre 1 al  31.2 % mentre 2 al  49.22 %. Valore vero:  2 indice:  18
# Valore predetto: 0 al  58.78 % mentre 1 al  27.22 % mentre 2 al  14.01 %. Valore vero:  0 indice:  19
# Valore predetto: 0 al  81.14 % mentre 1 al  13.6 % mentre 2 al  5.26 %. Valore vero:  0 indice:  20
# Valore predetto: 0 al  16.14 % mentre 1 al  28.37 % mentre 2 al  55.49 %. Valore vero:  0 indice:  21
# Valore predetto: 0 al  35.81 % mentre 1 al  34.36 % mentre 2 al  29.83 %. Valore vero:  1 indice:  22
# Valore predetto: 0 al  9.7 % mentre 1 al  22.31 % mentre 2 al  68.0 %. Valore vero:  2 indice:  23
# Valore predetto: 0 al  12.46 % mentre 1 al  24.72 % mentre 2 al  62.82 %. Valore vero:  2 indice:  24
# Valore predetto: 0 al  44.42 % mentre 1 al  33.08 % mentre 2 al  22.5 %. Valore vero:  2 indice:  25
# Valore predetto: 0 al  10.92 % mentre 1 al  24.03 % mentre 2 al  65.05 %. Valore vero:  2 indice:  26
# Valore predetto: 0 al  30.18 % mentre 1 al  34.83 % mentre 2 al  34.99 %. Valore vero:  2 indice:  27
# Valore predetto: 0 al  57.42 % mentre 1 al  27.74 % mentre 2 al  14.84 %. Valore vero:  0 indice:  28
# Valore predetto: 0 al  21.48 % mentre 1 al  32.32 % mentre 2 al  46.2 %. Valore vero:  0 indice:  29
# Valore predetto: 0 al  5.5 % mentre 1 al  14.08 % mentre 2 al  80.42 %. Valore vero:  2 indice:  30
# Valore predetto: 0 al  28.72 % mentre 1 al  35.09 % mentre 2 al  36.18 %. Valore vero:  1 indice:  31
# Valore predetto: 0 al  37.85 % mentre 1 al  33.94 % mentre 2 al  28.2 %. Valore vero:  0 indice:  32
# Valore predetto: 0 al  9.48 % mentre 1 al  21.25 % mentre 2 al  69.27 %. Valore vero:  2 indice:  33
# Valore predetto: 0 al  7.2 % mentre 1 al  18.04 % mentre 2 al  74.76 %. Valore vero:  2 indice:  34
# Valore predetto: 0 al  9.83 % mentre 1 al  21.6 % mentre 2 al  68.58 %. Valore vero:  1 indice:  35
# Valore predetto: 0 al  39.48 % mentre 1 al  34.33 % mentre 2 al  26.18 %. Valore vero:  1 indice:  36
# Valore predetto: 0 al  29.7 % mentre 1 al  34.74 % mentre 2 al  35.56 %. Valore vero:  2 indice:  37
# Valore predetto: 0 al  12.62 % mentre 1 al  25.71 % mentre 2 al  61.67 %. Valore vero:  1 indice:  38
# Valore predetto: 0 al  7.75 % mentre 1 al  18.64 % mentre 2 al  73.6 %. Valore vero:  2 indice:  39
# Valore predetto: 0 al  12.65 % mentre 1 al  25.66 % mentre 2 al  61.68 %. Valore vero:  2 indice:  40
# Valore predetto: 0 al  26.2 % mentre 1 al  33.78 % mentre 2 al  40.02 %. Valore vero:  2 indice:  41
# Valore predetto: 0 al  36.96 % mentre 1 al  33.96 % mentre 2 al  29.08 %. Valore vero:  0 indice:  42
# Valore predetto: 0 al  49.54 % mentre 1 al  31.51 % mentre 2 al  18.95 %. Valore vero:  2 indice:  43
# Valore predetto: 0 al  47.88 % mentre 1 al  31.92 % mentre 2 al  20.21 %. Valore vero:  0 indice:  44
# Valore predetto: 0 al  91.28 % mentre 1 al  6.44 % mentre 2 al  2.28 %. Valore vero:  0 indice:  45
# Valore predetto: 0 al  13.47 % mentre 1 al  26.38 % mentre 2 al  60.15 %. Valore vero:  2 indice:  46
# Valore predetto: 0 al  14.35 % mentre 1 al  27.1 % mentre 2 al  58.54 %. Valore vero:  1 indice:  47
# Valore predetto: 0 al  51.81 % mentre 1 al  30.16 % mentre 2 al  18.03 %. Valore vero:  0 indice:  48
# Valore predetto: 0 al  13.64 % mentre 1 al  26.8 % mentre 2 al  59.56 %. Valore vero:  2 indice:  49
# Valore predetto: 0 al  32.24 % mentre 1 al  34.29 % mentre 2 al  33.47 %. Valore vero:  1 indice:  50
# Valore predetto: 0 al  32.74 % mentre 1 al  34.29 % mentre 2 al  32.98 %. Valore vero:  1 indice:  51
# Valore predetto: 0 al  7.67 % mentre 1 al  19.11 % mentre 2 al  73.22 %. Valore vero:  2 indice:  52
# Valore predetto: 0 al  3.86 % mentre 1 al  10.06 % mentre 2 al  86.08 %. Valore vero:  2 indice:  53
# Valore predetto: 0 al  10.49 % mentre 1 al  22.44 % mentre 2 al  67.07 %. Valore vero:  2 indice:  54
# Valore predetto: 0 al  11.69 % mentre 1 al  24.27 % mentre 2 al  64.04 %. Valore vero:  2 indice:  55
# Valore predetto: 0 al  43.97 % mentre 1 al  33.46 % mentre 2 al  22.57 %. Valore vero:  0 indice:  56
# Valore predetto: 0 al  30.78 % mentre 1 al  33.94 % mentre 2 al  35.28 %. Valore vero:  1 indice:  57
# Valore predetto: 0 al  23.8 % mentre 1 al  33.7 % mentre 2 al  42.5 %. Valore vero:  0 indice:  58
# Valore predetto: 0 al  13.9 % mentre 1 al  27.09 % mentre 2 al  59.01 %. Valore vero:  2 indice:  59
# Valore predetto: 0 al  18.66 % mentre 1 al  30.72 % mentre 2 al  50.62 %. Valore vero:  2 indice:  60
# Valore predetto: 0 al  31.64 % mentre 1 al  34.72 % mentre 2 al  33.65 %. Valore vero:  2 indice:  61
# Valore predetto: 0 al  32.29 % mentre 1 al  34.32 % mentre 2 al  33.4 %. Valore vero:  2 indice:  62
# Valore predetto: 0 al  64.76 % mentre 1 al  23.93 % mentre 2 al  11.31 %. Valore vero:  0 indice:  63
# Valore predetto: 0 al  13.75 % mentre 1 al  27.03 % mentre 2 al  59.22 %. Valore vero:  2 indice:  64
# Valore predetto: 0 al  40.97 % mentre 1 al  33.51 % mentre 2 al  25.52 %. Valore vero:  0 indice:  65
# Valore predetto: 0 al  15.82 % mentre 1 al  29.09 % mentre 2 al  55.08 %. Valore vero:  2 indice:  66
# Valore predetto: 0 al  16.18 % mentre 1 al  29.3 % mentre 2 al  54.51 %. Valore vero:  0 indice:  67
# Valore predetto: 0 al  21.65 % mentre 1 al  32.23 % mentre 2 al  46.12 %. Valore vero:  2 indice:  68
# Valore predetto: 0 al  16.62 % mentre 1 al  28.96 % mentre 2 al  54.42 %. Valore vero:  2 indice:  69
# Valore predetto: 0 al  16.11 % mentre 1 al  29.04 % mentre 2 al  54.85 %. Valore vero:  2 indice:  70
# Valore predetto: 0 al  35.62 % mentre 1 al  35.17 % mentre 2 al  29.2 %. Valore vero:  0 indice:  71
# Valore predetto: 0 al  81.51 % mentre 1 al  13.64 % mentre 2 al  4.86 %. Valore vero:  0 indice:  72
# Valore predetto: 0 al  29.23 % mentre 1 al  34.52 % mentre 2 al  36.25 %. Valore vero:  0 indice:  73
# Valore predetto: 0 al  18.4 % mentre 1 al  30.58 % mentre 2 al  51.02 %. Valore vero:  0 indice:  74
# Valore predetto: 0 al  12.91 % mentre 1 al  25.67 % mentre 2 al  61.42 %. Valore vero:  2 indice:  75
# Valore predetto: 0 al  6.37 % mentre 1 al  16.12 % mentre 2 al  77.5 %. Valore vero:  2 indice:  76
# Valore predetto: 0 al  9.04 % mentre 1 al  19.54 % mentre 2 al  71.42 %. Valore vero:  2 indice:  77
# Valore predetto: 0 al  45.36 % mentre 1 al  32.83 % mentre 2 al  21.82 %. Valore vero:  0 indice:  78
# Valore predetto: 0 al  4.76 % mentre 1 al  12.54 % mentre 2 al  82.7 %. Valore vero:  1 indice:  79
# Valore predetto: 0 al  18.67 % mentre 1 al  30.46 % mentre 2 al  50.88 %. Valore vero:  0 indice:  80
# Valore predetto: 0 al  59.78 % mentre 1 al  26.58 % mentre 2 al  13.64 %. Valore vero:  0 indice:  81
# Valore predetto: 0 al  45.46 % mentre 1 al  32.24 % mentre 2 al  22.3 %. Valore vero:  1 indice:  82
# Valore predetto: 0 al  59.77 % mentre 1 al  26.82 % mentre 2 al  13.41 %. Valore vero:  0 indice:  83
# Valore predetto: 0 al  8.22 % mentre 1 al  18.7 % mentre 2 al  73.07 %. Valore vero:  1 indice:  84
# Valore predetto: 0 al  34.2 % mentre 1 al  34.04 % mentre 2 al  31.76 %. Valore vero:  1 indice:  85
# Valore predetto: 0 al  21.12 % mentre 1 al  32.04 % mentre 2 al  46.84 %. Valore vero:  2 indice:  86
# Valore predetto: 0 al  42.9 % mentre 1 al  33.07 % mentre 2 al  24.02 %. Valore vero:  0 indice:  87
# Valore predetto: 0 al  21.9 % mentre 1 al  32.2 % mentre 2 al  45.9 %. Valore vero:  1 indice:  88
# Valore predetto: 0 al  31.82 % mentre 1 al  34.67 % mentre 2 al  33.51 %. Valore vero:  2 indice:  89
# Valore predetto: 0 al  80.28 % mentre 1 al  14.22 % mentre 2 al  5.49 %. Valore vero:  0 indice:  90
# Valore predetto: 0 al  17.6 % mentre 1 al  30.36 % mentre 2 al  52.04 %. Valore vero:  1 indice:  91
# Valore predetto: 0 al  13.48 % mentre 1 al  26.6 % mentre 2 al  59.92 %. Valore vero:  2 indice:  92
# Valore predetto: 0 al  12.98 % mentre 1 al  26.41 % mentre 2 al  60.61 %. Valore vero:  1 indice:  93
# Valore predetto: 0 al  16.78 % mentre 1 al  29.44 % mentre 2 al  53.79 %. Valore vero:  2 indice:  94
# Valore predetto: 0 al  11.36 % mentre 1 al  23.62 % mentre 2 al  65.02 %. Valore vero:  1 indice:  95
# Valore predetto: 0 al  8.57 % mentre 1 al  20.81 % mentre 2 al  70.62 %. Valore vero:  1 indice:  96
# Valore predetto: 0 al  14.7 % mentre 1 al  28.25 % mentre 2 al  57.06 %. Valore vero:  0 indice:  97
# Valore predetto: 0 al  37.16 % mentre 1 al  33.97 % mentre 2 al  28.87 %. Valore vero:  0 indice:  98
# Valore predetto: 0 al  8.85 % mentre 1 al  19.58 % mentre 2 al  71.56 %. Valore vero:  2 indice:  99
# Valore predetto: 0 al  3.91 % mentre 1 al  11.0 % mentre 2 al  85.08 %. Valore vero:  2 indice:  100
# Valore predetto: 0 al  17.66 % mentre 1 al  29.98 % mentre 2 al  52.36 %. Valore vero:  1 indice:  101
# Valore predetto: 0 al  12.4 % mentre 1 al  24.38 % mentre 2 al  63.22 %. Valore vero:  2 indice:  102
# Valore predetto: 0 al  5.12 % mentre 1 al  13.67 % mentre 2 al  81.22 %. Valore vero:  2 indice:  103
# Valore predetto: 0 al  38.82 % mentre 1 al  34.56 % mentre 2 al  26.62 %. Valore vero:  0 indice:  104
# Valore predetto: 0 al  58.22 % mentre 1 al  27.01 % mentre 2 al  14.77 %. Valore vero:  0 indice:  105
# Valore predetto: 0 al  20.32 % mentre 1 al  31.84 % mentre 2 al  47.84 %. Valore vero:  2 indice:  106
# Valore predetto: 0 al  18.62 % mentre 1 al  31.58 % mentre 2 al  49.79 %. Valore vero:  1 indice:  107
# Valore predetto: 0 al  28.55 % mentre 1 al  34.34 % mentre 2 al  37.11 %. Valore vero:  0 indice:  108
# Valore predetto: 0 al  37.38 % mentre 1 al  34.49 % mentre 2 al  28.13 %. Valore vero:  0 indice:  109
# Valore predetto: 0 al  41.72 % mentre 1 al  33.38 % mentre 2 al  24.91 %. Valore vero:  1 indice:  110
# Valore predetto: 0 al  38.28 % mentre 1 al  33.78 % mentre 2 al  27.94 %. Valore vero:  0 indice:  111
# Valore predetto: 0 al  20.1 % mentre 1 al  31.87 % mentre 2 al  48.02 %. Valore vero:  1 indice:  112
# Valore predetto: 0 al  32.25 % mentre 1 al  34.87 % mentre 2 al  32.88 %. Valore vero:  0 indice:  113
# Valore predetto: 0 al  47.48 % mentre 1 al  32.04 % mentre 2 al  20.47 %. Valore vero:  2 indice:  114
# Valore predetto: 0 al  40.26 % mentre 1 al  34.06 % mentre 2 al  25.68 %. Valore vero:  1 indice:  115
# Valore predetto: 0 al  25.9 % mentre 1 al  34.3 % mentre 2 al  39.8 %. Valore vero:  2 indice:  116
# Valore predetto: 0 al  57.12 % mentre 1 al  27.53 % mentre 2 al  15.34 %. Valore vero:  0 indice:  117
# Valore predetto: 0 al  24.72 % mentre 1 al  33.31 % mentre 2 al  41.96 %. Valore vero:  2 indice:  118
# Valore predetto: 0 al  28.4 % mentre 1 al  33.97 % mentre 2 al  37.64 %. Valore vero:  1 indice:  119
# Valore predetto: 0 al  9.7 % mentre 1 al  22.25 % mentre 2 al  68.05 %. Valore vero:  2 indice:  120
# Valore predetto: 0 al  7.6 % mentre 1 al  18.24 % mentre 2 al  74.16 %. Valore vero:  2 indice:  121
# Valore predetto: 0 al  44.96 % mentre 1 al  32.78 % mentre 2 al  22.26 %. Valore vero:  2 indice:  122
# Valore predetto: 0 al  26.02 % mentre 1 al  34.08 % mentre 2 al  39.9 %. Valore vero:  1 indice:  123
# Valore predetto: 0 al  35.18 % mentre 1 al  34.88 % mentre 2 al  29.94 %. Valore vero:  2 indice:  124
# Valore predetto: 0 al  21.47 % mentre 1 al  33.34 % mentre 2 al  45.18 %. Valore vero:  1 indice:  125
# Valore predetto: 0 al  22.12 % mentre 1 al  32.88 % mentre 2 al  44.99 %. Valore vero:  1 indice:  126
# Valore predetto: 0 al  3.76 % mentre 1 al  10.66 % mentre 2 al  85.58 %. Valore vero:  1 indice:  127
# Valore predetto: 0 al  33.88 % mentre 1 al  34.64 % mentre 2 al  31.48 %. Valore vero:  2 indice:  128
# Valore predetto: 0 al  35.08 % mentre 1 al  34.78 % mentre 2 al  30.15 %. Valore vero:  1 indice:  129
# Valore predetto: 0 al  58.83 % mentre 1 al  26.68 % mentre 2 al  14.49 %. Valore vero:  0 indice:  130
# Valore predetto: 0 al  12.98 % mentre 1 al  25.52 % mentre 2 al  61.49 %. Valore vero:  2 indice:  131
# Valore predetto: 0 al  14.78 % mentre 1 al  27.27 % mentre 2 al  57.94 %. Valore vero:  1 indice:  132
# Valore predetto: 0 al  70.51 % mentre 1 al  20.52 % mentre 2 al  8.98 %. Valore vero:  1 indice:  133
# Valore predetto: 0 al  43.06 % mentre 1 al  33.53 % mentre 2 al  23.41 %. Valore vero:  1 indice:  134
# Valore predetto: 0 al  17.3 % mentre 1 al  29.3 % mentre 2 al  53.4 %. Valore vero:  2 indice:  135
# Valore predetto: 0 al  38.13 % mentre 1 al  34.69 % mentre 2 al  27.18 %. Valore vero:  1 indice:  136
# Valore predetto: 0 al  14.26 % mentre 1 al  27.21 % mentre 2 al  58.53 %. Valore vero:  1 indice:  137
# Valore predetto: 0 al  19.52 % mentre 1 al  31.13 % mentre 2 al  49.35 %. Valore vero:  2 indice:  138
# Valore predetto: 0 al  49.5 % mentre 1 al  31.04 % mentre 2 al  19.45 %. Valore vero:  0 indice:  139
# Valore predetto: 0 al  16.74 % mentre 1 al  28.18 % mentre 2 al  55.08 %. Valore vero:  2 indice:  140
# Valore predetto: 0 al  32.77 % mentre 1 al  34.25 % mentre 2 al  32.98 %. Valore vero:  1 indice:  141
# Valore predetto: 0 al  23.42 % mentre 1 al  33.53 % mentre 2 al  43.04 %. Valore vero:  1 indice:  142
# Valore predetto: 0 al  4.98 % mentre 1 al  13.06 % mentre 2 al  81.96 %. Valore vero:  2 indice:  143
# Valore predetto: 0 al  17.23 % mentre 1 al  29.9 % mentre 2 al  52.86 %. Valore vero:  2 indice:  144
# Valore predetto: 0 al  19.08 % mentre 1 al  30.34 % mentre 2 al  50.58 %. Valore vero:  1 indice:  145
# Valore predetto: 0 al  18.34 % mentre 1 al  30.33 % mentre 2 al  51.34 %. Valore vero:  1 indice:  146
# Valore predetto: 0 al  15.9 % mentre 1 al  28.54 % mentre 2 al  55.56 %. Valore vero:  1 indice:  147
# Valore predetto: 0 al  12.3 % mentre 1 al  25.23 % mentre 2 al  62.48 %. Valore vero:  1 indice:  148
# Valore predetto: 0 al  38.58 % mentre 1 al  33.87 % mentre 2 al  27.54 %. Valore vero:  0 indice:  149
# Valore predetto: 0 al  12.8 % mentre 1 al  25.42 % mentre 2 al  61.78 %. Valore vero:  2 indice:  150
# Valore predetto: 0 al  77.83 % mentre 1 al  15.72 % mentre 2 al  6.46 %. Valore vero:  0 indice:  151
# Valore predetto: 0 al  52.32 % mentre 1 al  30.4 % mentre 2 al  17.27 %. Valore vero:  0 indice:  152
# Valore predetto: 0 al  6.93 % mentre 1 al  16.28 % mentre 2 al  76.79 %. Valore vero:  2 indice:  153
# Valore predetto: 0 al  54.76 % mentre 1 al  28.8 % mentre 2 al  16.43 %. Valore vero:  0 indice:  154
# Valore predetto: 0 al  13.26 % mentre 1 al  26.07 % mentre 2 al  60.66 %. Valore vero:  2 indice:  155
# Valore predetto: 0 al  26.52 % mentre 1 al  34.14 % mentre 2 al  39.34 %. Valore vero:  2 indice:  156
# Valore predetto: 0 al  15.47 % mentre 1 al  27.86 % mentre 2 al  56.68 %. Valore vero:  1 indice:  157
# Valore predetto: 0 al  37.44 % mentre 1 al  34.22 % mentre 2 al  28.34 %. Valore vero:  2 indice:  158
# Valore predetto: 0 al  40.59 % mentre 1 al  33.6 % mentre 2 al  25.82 %. Valore vero:  1 indice:  159
# Valore predetto: 0 al  75.8 % mentre 1 al  17.1 % mentre 2 al  7.1 %. Valore vero:  1 indice:  160
# Valore predetto: 0 al  32.03 % mentre 1 al  34.76 % mentre 2 al  33.2 %. Valore vero:  0 indice:  161
# Valore predetto: 0 al  23.75 % mentre 1 al  33.56 % mentre 2 al  42.68 %. Valore vero:  2 indice:  162
# Valore predetto: 0 al  10.12 % mentre 1 al  21.83 % mentre 2 al  68.04 %. Valore vero:  2 indice:  163
# Valore predetto: 0 al  14.9 % mentre 1 al  27.62 % mentre 2 al  57.48 %. Valore vero:  2 indice:  164
# Valore predetto: 0 al  8.62 % mentre 1 al  20.76 % mentre 2 al  70.62 %. Valore vero:  0 indice:  165
# Valore predetto: 0 al  8.86 % mentre 1 al  20.03 % mentre 2 al  71.11 %. Valore vero:  2 indice:  166
# Valore predetto: 0 al  17.68 % mentre 1 al  30.4 % mentre 2 al  51.92 %. Valore vero:  1 indice:  167
# Valore predetto: 0 al  26.15 % mentre 1 al  34.17 % mentre 2 al  39.68 %. Valore vero:  1 indice:  168
# Valore predetto: 0 al  22.06 % mentre 1 al  32.88 % mentre 2 al  45.06 %. Valore vero:  1 indice:  169
# Valore predetto: 0 al  75.58 % mentre 1 al  17.03 % mentre 2 al  7.39 %. Valore vero:  1 indice:  170
# Valore predetto: 0 al  49.36 % mentre 1 al  31.96 % mentre 2 al  18.68 %. Valore vero:  0 indice:  171
# Valore predetto: 0 al  18.06 % mentre 1 al  30.4 % mentre 2 al  51.54 %. Valore vero:  2 indice:  172
# Valore predetto: 0 al  16.58 % mentre 1 al  28.69 % mentre 2 al  54.74 %. Valore vero:  0 indice:  173
# Valore predetto: 0 al  57.96 % mentre 1 al  27.06 % mentre 2 al  14.98 %. Valore vero:  1 indice:  174
# Valore predetto: 0 al  38.29 % mentre 1 al  34.49 % mentre 2 al  27.22 %. Valore vero:  2 indice:  175
# Valore predetto: 0 al  20.92 % mentre 1 al  32.52 % mentre 2 al  46.56 %. Valore vero:  2 indice:  176
# Valore predetto: 0 al  10.67 % mentre 1 al  23.17 % mentre 2 al  66.16 %. Valore vero:  2 indice:  177
# Valore predetto: 0 al  23.08 % mentre 1 al  32.71 % mentre 2 al  44.21 %. Valore vero:  1 indice:  178
# Valore predetto: 0 al  14.31 % mentre 1 al  27.57 % mentre 2 al  58.13 %. Valore vero:  2 indice:  179
# Valore predetto: 0 al  39.86 % mentre 1 al  33.45 % mentre 2 al  26.7 %. Valore vero:  2 indice:  180
# Valore predetto: 0 al  48.3 % mentre 1 al  31.2 % mentre 2 al  20.5 %. Valore vero:  0 indice:  181
# Valore predetto: 0 al  13.5 % mentre 1 al  27.0 % mentre 2 al  59.5 %. Valore vero:  1 indice:  182
# Valore predetto: 0 al  9.25 % mentre 1 al  21.26 % mentre 2 al  69.5 %. Valore vero:  2 indice:  183
# Valore predetto: 0 al  26.72 % mentre 1 al  33.97 % mentre 2 al  39.32 %. Valore vero:  1 indice:  184
# Valore predetto: 0 al  13.84 % mentre 1 al  26.48 % mentre 2 al  59.68 %. Valore vero:  2 indice:  185
# Valore predetto: 0 al  4.82 % mentre 1 al  12.36 % mentre 2 al  82.82 %. Valore vero:  2 indice:  186
# Valore predetto: 0 al  36.84 % mentre 1 al  34.18 % mentre 2 al  28.98 %. Valore vero:  0 indice:  187
# Valore predetto: 0 al  22.6 % mentre 1 al  33.08 % mentre 2 al  44.32 %. Valore vero:  0 indice:  188
# Valore predetto: 0 al  27.07 % mentre 1 al  33.57 % mentre 2 al  39.36 %. Valore vero:  2 indice:  189
# Valore predetto: 0 al  16.99 % mentre 1 al  29.51 % mentre 2 al  53.5 %. Valore vero:  1 indice:  190
# Valore predetto: 0 al  25.2 % mentre 1 al  34.72 % mentre 2 al  40.08 %. Valore vero:  2 indice:  191
# Valore predetto: 0 al  41.01 % mentre 1 al  33.56 % mentre 2 al  25.43 %. Valore vero:  0 indice:  192
# Valore predetto: 0 al  13.12 % mentre 1 al  26.2 % mentre 2 al  60.67 %. Valore vero:  1 indice:  193
# Valore predetto: 0 al  17.09 % mentre 1 al  29.78 % mentre 2 al  53.13 %. Valore vero:  1 indice:  194
# Valore predetto: 0 al  58.88 % mentre 1 al  27.15 % mentre 2 al  13.96 %. Valore vero:  0 indice:  195
# Valore predetto: 0 al  14.64 % mentre 1 al  27.28 % mentre 2 al  58.08 %. Valore vero:  2 indice:  196
# Valore predetto: 0 al  17.26 % mentre 1 al  29.16 % mentre 2 al  53.59 %. Valore vero:  1 indice:  197
# Valore predetto: 0 al  22.34 % mentre 1 al  32.29 % mentre 2 al  45.38 %. Valore vero:  0 indice:  198
# Valore predetto: 0 al  3.54 % mentre 1 al  9.55 % mentre 2 al  86.92 %. Valore vero:  2 indice:  199
# Valore predetto: 0 al  33.65 % mentre 1 al  34.8 % mentre 2 al  31.56 %. Valore vero:  1 indice:  200
# Valore predetto: 0 al  15.32 % mentre 1 al  28.94 % mentre 2 al  55.74 %. Valore vero:  2 indice:  201
# Valore predetto: 0 al  14.38 % mentre 1 al  27.49 % mentre 2 al  58.13 %. Valore vero:  2 indice:  202
# Valore predetto: 0 al  31.4 % mentre 1 al  34.79 % mentre 2 al  33.81 %. Valore vero:  1 indice:  203
# Valore predetto: 0 al  23.48 % mentre 1 al  33.24 % mentre 2 al  43.28 %. Valore vero:  0 indice:  204
# Valore predetto: 0 al  43.33 % mentre 1 al  33.14 % mentre 2 al  23.53 %. Valore vero:  0 indice:  205
# Valore predetto: 0 al  69.6 % mentre 1 al  20.99 % mentre 2 al  9.41 %. Valore vero:  0 indice:  206
# Valore predetto: 0 al  29.31 % mentre 1 al  35.3 % mentre 2 al  35.39 %. Valore vero:  0 indice:  207
# Valore predetto: 0 al  47.24 % mentre 1 al  32.04 % mentre 2 al  20.72 %. Valore vero:  2 indice:  208
# Valore predetto: 0 al  19.63 % mentre 1 al  31.55 % mentre 2 al  48.82 %. Valore vero:  0 indice:  209
# Valore predetto: 0 al  16.63 % mentre 1 al  28.82 % mentre 2 al  54.56 %. Valore vero:  1 indice:  210
# Valore predetto: 0 al  9.58 % mentre 1 al  21.34 % mentre 2 al  69.08 %. Valore vero:  1 indice:  211
# Valore predetto: 0 al  10.22 % mentre 1 al  22.44 % mentre 2 al  67.34 %. Valore vero:  2 indice:  212
# Valore predetto: 0 al  21.64 % mentre 1 al  33.16 % mentre 2 al  45.2 %. Valore vero:  1 indice:  213
# Valore predetto: 0 al  9.04 % mentre 1 al  20.18 % mentre 2 al  70.78 %. Valore vero:  0 indice:  214
# Valore predetto: 0 al  20.88 % mentre 1 al  32.53 % mentre 2 al  46.59 %. Valore vero:  1 indice:  215
# Valore predetto: 0 al  38.4 % mentre 1 al  33.88 % mentre 2 al  27.72 %. Valore vero:  1 indice:  216
# Valore predetto: 0 al  27.62 % mentre 1 al  34.39 % mentre 2 al  38.0 %. Valore vero:  1 indice:  217
# Valore predetto: 0 al  32.53 % mentre 1 al  34.96 % mentre 2 al  32.51 %. Valore vero:  0 indice:  218
# Valore predetto: 0 al  66.44 % mentre 1 al  23.28 % mentre 2 al  10.27 %. Valore vero:  0 indice:  219
# Valore predetto: 0 al  10.29 % mentre 1 al  22.38 % mentre 2 al  67.32 %. Valore vero:  2 indice:  220
# Valore predetto: 0 al  62.13 % mentre 1 al  25.07 % mentre 2 al  12.8 %. Valore vero:  0 indice:  221
# Valore predetto: 0 al  35.3 % mentre 1 al  34.28 % mentre 2 al  30.41 %. Valore vero:  1 indice:  222
# Valore predetto: 0 al  52.04 % mentre 1 al  30.46 % mentre 2 al  17.51 %. Valore vero:  0 indice:  223
# Valore predetto: 0 al  23.78 % mentre 1 al  33.78 % mentre 2 al  42.44 %. Valore vero:  2 indice:  224
# Valore predetto: 0 al  27.35 % mentre 1 al  34.37 % mentre 2 al  38.29 %. Valore vero:  1 indice:  225
# Valore predetto: 0 al  9.66 % mentre 1 al  21.72 % mentre 2 al  68.61 %. Valore vero:  2 indice:  226
# Valore predetto: 0 al  11.78 % mentre 1 al  24.7 % mentre 2 al  63.52 %. Valore vero:  0 indice:  227
# Valore predetto: 0 al  69.36 % mentre 1 al  21.54 % mentre 2 al  9.11 %. Valore vero:  0 indice:  228
# Valore predetto: 0 al  20.54 % mentre 1 al  31.99 % mentre 2 al  47.48 %. Valore vero:  2 indice:  229
# Valore predetto: 0 al  4.7 % mentre 1 al  12.75 % mentre 2 al  82.56 %. Valore vero:  2 indice:  230
# Valore predetto: 0 al  27.24 % mentre 1 al  35.2 % mentre 2 al  37.56 %. Valore vero:  0 indice:  231
# Valore predetto: 0 al  34.06 % mentre 1 al  34.16 % mentre 2 al  31.79 %. Valore vero:  2 indice:  232
# Valore predetto: 0 al  32.28 % mentre 1 al  35.4 % mentre 2 al  32.32 %. Valore vero:  2 indice:  233
# Valore predetto: 0 al  31.74 % mentre 1 al  34.71 % mentre 2 al  33.55 %. Valore vero:  2 indice:  234
# Valore predetto: 0 al  19.5 % mentre 1 al  31.21 % mentre 2 al  49.3 %. Valore vero:  2 indice:  235
# Valore predetto: 0 al  12.01 % mentre 1 al  24.14 % mentre 2 al  63.86 %. Valore vero:  1 indice:  236
# Valore predetto: 0 al  23.36 % mentre 1 al  33.07 % mentre 2 al  43.57 %. Valore vero:  0 indice:  237
# Valore predetto: 0 al  20.06 % mentre 1 al  31.13 % mentre 2 al  48.82 %. Valore vero:  2 indice:  238
# Valore predetto: 0 al  10.63 % mentre 1 al  23.67 % mentre 2 al  65.7 %. Valore vero:  2 indice:  239
# Valore predetto: 0 al  6.86 % mentre 1 al  16.5 % mentre 2 al  76.64 %. Valore vero:  2 indice:  240
# Valore predetto: 0 al  62.38 % mentre 1 al  24.78 % mentre 2 al  12.84 %. Valore vero:  0 indice:  241
# Valore predetto: 0 al  32.2 % mentre 1 al  35.11 % mentre 2 al  32.7 %. Valore vero:  2 indice:  242
# Valore predetto: 0 al  84.89 % mentre 1 al  10.82 % mentre 2 al  4.28 %. Valore vero:  0 indice:  243
# Valore predetto: 0 al  43.18 % mentre 1 al  33.03 % mentre 2 al  23.79 %. Valore vero:  1 indice:  244
# Valore predetto: 0 al  30.24 % mentre 1 al  34.63 % mentre 2 al  35.13 %. Valore vero:  1 indice:  245
# Valore predetto: 0 al  59.39 % mentre 1 al  26.54 % mentre 2 al  14.06 %. Valore vero:  0 indice:  246
# Valore predetto: 0 al  13.76 % mentre 1 al  26.86 % mentre 2 al  59.37 %. Valore vero:  2 indice:  247
# Valore predetto: 0 al  19.94 % mentre 1 al  32.05 % mentre 2 al  48.01 %. Valore vero:  1 indice:  248
# Valore predetto: 0 al  45.55 % mentre 1 al  32.64 % mentre 2 al  21.81 %. Valore vero:  2 indice:  249
# Valore predetto: 0 al  35.84 % mentre 1 al  34.65 % mentre 2 al  29.51 %. Valore vero:  1 indice:  250
# Valore predetto: 0 al  28.06 % mentre 1 al  34.11 % mentre 2 al  37.83 %. Valore vero:  2 indice:  251
# Valore predetto: 0 al  15.13 % mentre 1 al  27.92 % mentre 2 al  56.94 %. Valore vero:  2 indice:  252
# Valore predetto: 0 al  20.14 % mentre 1 al  31.48 % mentre 2 al  48.38 %. Valore vero:  2 indice:  253
# Valore predetto: 0 al  12.7 % mentre 1 al  26.44 % mentre 2 al  60.86 %. Valore vero:  1 indice:  254
# Valore predetto: 0 al  48.02 % mentre 1 al  31.23 % mentre 2 al  20.74 %. Valore vero:  0 indice:  255
# Valore predetto: 0 al  34.72 % mentre 1 al  34.47 % mentre 2 al  30.82 %. Valore vero:  0 indice:  256
# Valore predetto: 0 al  13.28 % mentre 1 al  25.99 % mentre 2 al  60.73 %. Valore vero:  2 indice:  257
# Valore predetto: 0 al  21.43 % mentre 1 al  32.67 % mentre 2 al  45.9 %. Valore vero:  2 indice:  258
# Valore predetto: 0 al  5.51 % mentre 1 al  14.88 % mentre 2 al  79.62 %. Valore vero:  2 indice:  259
# Valore predetto: 0 al  59.38 % mentre 1 al  26.62 % mentre 2 al  14.0 %. Valore vero:  0 indice:  260
# Valore predetto: 0 al  24.7 % mentre 1 al  33.19 % mentre 2 al  42.1 %. Valore vero:  2 indice:  261
# Valore predetto: 0 al  28.45 % mentre 1 al  34.2 % mentre 2 al  37.35 %. Valore vero:  2 indice:  262
# Valore predetto: 0 al  24.74 % mentre 1 al  33.06 % mentre 2 al  42.21 %. Valore vero:  1 indice:  263
# Valore predetto: 0 al  63.09 % mentre 1 al  24.62 % mentre 2 al  12.3 %. Valore vero:  0 indice:  264
# Valore predetto: 0 al  15.74 % mentre 1 al  28.18 % mentre 2 al  56.08 %. Valore vero:  2 indice:  265
# Valore predetto: 0 al  25.36 % mentre 1 al  33.96 % mentre 2 al  40.68 %. Valore vero:  0 indice:  266
# Valore predetto: 0 al  45.41 % mentre 1 al  32.71 % mentre 2 al  21.88 %. Valore vero:  1 indice:  267
# Valore predetto: 0 al  8.83 % mentre 1 al  19.84 % mentre 2 al  71.32 %. Valore vero:  2 indice:  268
# Valore predetto: 0 al  19.96 % mentre 1 al  31.86 % mentre 2 al  48.19 %. Valore vero:  2 indice:  269
# Valore predetto: 0 al  25.72 % mentre 1 al  33.43 % mentre 2 al  40.86 %. Valore vero:  0 indice:  270
# Valore predetto: 0 al  40.32 % mentre 1 al  33.96 % mentre 2 al  25.73 %. Valore vero:  2 indice:  271
# Valore predetto: 0 al  14.1 % mentre 1 al  26.9 % mentre 2 al  59.0 %. Valore vero:  0 indice:  272
# Valore predetto: 0 al  12.57 % mentre 1 al  25.62 % mentre 2 al  61.82 %. Valore vero:  1 indice:  273
# Valore predetto: 0 al  19.88 % mentre 1 al  31.36 % mentre 2 al  48.76 %. Valore vero:  2 indice:  274
# Valore predetto: 0 al  70.42 % mentre 1 al  20.4 % mentre 2 al  9.18 %. Valore vero:  2 indice:  275
# Valore predetto: 0 al  25.15 % mentre 1 al  33.05 % mentre 2 al  41.8 %. Valore vero:  2 indice:  276
# Valore predetto: 0 al  26.64 % mentre 1 al  34.27 % mentre 2 al  39.09 %. Valore vero:  0 indice:  277
# Valore predetto: 0 al  7.03 % mentre 1 al  17.25 % mentre 2 al  75.72 %. Valore vero:  2 indice:  278
# Valore predetto: 0 al  42.05 % mentre 1 al  33.53 % mentre 2 al  24.42 %. Valore vero:  0 indice:  279
# Valore predetto: 0 al  3.26 % mentre 1 al  9.73 % mentre 2 al  87.0 %. Valore vero:  2 indice:  280
# Valore predetto: 0 al  25.62 % mentre 1 al  33.44 % mentre 2 al  40.94 %. Valore vero:  2 indice:  281
# Valore predetto: 0 al  23.7 % mentre 1 al  33.18 % mentre 2 al  43.11 %. Valore vero:  2 indice:  282
# Valore predetto: 0 al  39.36 % mentre 1 al  33.88 % mentre 2 al  26.76 %. Valore vero:  2 indice:  283
# Valore predetto: 0 al  21.87 % mentre 1 al  33.1 % mentre 2 al  45.03 %. Valore vero:  1 indice:  284
# Valore predetto: 0 al  53.04 % mentre 1 al  29.82 % mentre 2 al  17.14 %. Valore vero:  0 indice:  285
# Valore predetto: 0 al  24.51 % mentre 1 al  33.32 % mentre 2 al  42.16 %. Valore vero:  0 indice:  286
# Valore predetto: 0 al  39.98 % mentre 1 al  34.1 % mentre 2 al  25.92 %. Valore vero:  0 indice:  287
# Valore predetto: 0 al  39.21 % mentre 1 al  33.96 % mentre 2 al  26.83 %. Valore vero:  0 indice:  288
# Valore predetto: 0 al  74.58 % mentre 1 al  18.04 % mentre 2 al  7.38 %. Valore vero:  0 indice:  289
# Valore predetto: 0 al  10.39 % mentre 1 al  23.03 % mentre 2 al  66.58 %. Valore vero:  1 indice:  290
# Valore predetto: 0 al  55.56 % mentre 1 al  28.55 % mentre 2 al  15.89 %. Valore vero:  2 indice:  291
# Valore predetto: 0 al  60.26 % mentre 1 al  26.12 % mentre 2 al  13.61 %. Valore vero:  2 indice:  292
# Valore predetto: 0 al  37.16 % mentre 1 al  33.83 % mentre 2 al  29.02 %. Valore vero:  0 indice:  293
# Valore predetto: 0 al  14.14 % mentre 1 al  26.5 % mentre 2 al  59.36 %. Valore vero:  1 indice:  294
# Valore predetto: 0 al  44.32 % mentre 1 al  32.8 % mentre 2 al  22.88 %. Valore vero:  2 indice:  295
# Valore predetto: 0 al  29.75 % mentre 1 al  34.2 % mentre 2 al  36.05 %. Valore vero:  2 indice:  296
# Valore predetto: 0 al  15.47 % mentre 1 al  28.01 % mentre 2 al  56.52 %. Valore vero:  2 indice:  297
# Valore predetto: 0 al  11.67 % mentre 1 al  24.1 % mentre 2 al  64.24 %. Valore vero:  2 indice:  298
# Valore predetto: 0 al  9.55 % mentre 1 al  20.71 % mentre 2 al  69.74 %. Valore vero:  2 indice:  299
# Valore predetto: 0 al  42.45 % mentre 1 al  33.19 % mentre 2 al  24.36 %. Valore vero:  1 indice:  300
# Valore predetto: 0 al  26.74 % mentre 1 al  33.94 % mentre 2 al  39.32 %. Valore vero:  0 indice:  301
# Valore predetto: 0 al  24.68 % mentre 1 al  33.18 % mentre 2 al  42.14 %. Valore vero:  2 indice:  302
# Valore predetto: 0 al  10.06 % mentre 1 al  23.08 % mentre 2 al  66.86 %. Valore vero:  0 indice:  303
# Valore predetto: 0 al  22.36 % mentre 1 al  32.68 % mentre 2 al  44.96 %. Valore vero:  1 indice:  304
# Valore predetto: 0 al  19.78 % mentre 1 al  30.62 % mentre 2 al  49.6 %. Valore vero:  1 indice:  305
# Valore predetto: 0 al  6.21 % mentre 1 al  15.56 % mentre 2 al  78.23 %. Valore vero:  1 indice:  306
# Valore predetto: 0 al  17.08 % mentre 1 al  29.02 % mentre 2 al  53.9 %. Valore vero:  2 indice:  307
# Valore predetto: 0 al  20.42 % mentre 1 al  32.05 % mentre 2 al  47.53 %. Valore vero:  2 indice:  308
# Valore predetto: 0 al  23.45 % mentre 1 al  33.26 % mentre 2 al  43.29 %. Valore vero:  2 indice:  309
# Valore predetto: 0 al  13.68 % mentre 1 al  26.96 % mentre 2 al  59.36 %. Valore vero:  2 indice:  310
# Valore predetto: 0 al  78.5 % mentre 1 al  15.2 % mentre 2 al  6.3 %. Valore vero:  2 indice:  311
# Valore predetto: 0 al  77.52 % mentre 1 al  15.96 % mentre 2 al  6.52 %. Valore vero:  0 indice:  312
# Valore predetto: 0 al  10.58 % mentre 1 al  22.6 % mentre 2 al  66.82 %. Valore vero:  1 indice:  313
# Valore predetto: 0 al  72.56 % mentre 1 al  18.98 % mentre 2 al  8.47 %. Valore vero:  0 indice:  314
# Valore predetto: 0 al  14.41 % mentre 1 al  27.1 % mentre 2 al  58.5 %. Valore vero:  2 indice:  315
# Valore predetto: 0 al  26.48 % mentre 1 al  34.56 % mentre 2 al  38.96 %. Valore vero:  1 indice:  316
# Valore predetto: 0 al  17.1 % mentre 1 al  29.17 % mentre 2 al  53.74 %. Valore vero:  1 indice:  317
# Valore predetto: 0 al  11.9 % mentre 1 al  24.68 % mentre 2 al  63.42 %. Valore vero:  1 indice:  318
# Valore predetto: 0 al  14.72 % mentre 1 al  27.3 % mentre 2 al  57.98 %. Valore vero:  2 indice:  319
# Valore predetto: 0 al  40.0 % mentre 1 al  34.46 % mentre 2 al  25.54 %. Valore vero:  2 indice:  320
# Valore predetto: 0 al  16.72 % mentre 1 al  28.83 % mentre 2 al  54.46 %. Valore vero:  2 indice:  321
# Valore predetto: 0 al  27.38 % mentre 1 al  33.8 % mentre 2 al  38.82 %. Valore vero:  0 indice:  322
# Valore predetto: 0 al  28.8 % mentre 1 al  33.74 % mentre 2 al  37.46 %. Valore vero:  0 indice:  323
# Valore predetto: 0 al  23.3 % mentre 1 al  33.15 % mentre 2 al  43.54 %. Valore vero:  1 indice:  324
# Valore predetto: 0 al  5.76 % mentre 1 al  14.61 % mentre 2 al  79.64 %. Valore vero:  2 indice:  325
# Valore predetto: 0 al  9.71 % mentre 1 al  21.6 % mentre 2 al  68.69 %. Valore vero:  0 indice:  326
# Valore predetto: 0 al  38.32 % mentre 1 al  34.34 % mentre 2 al  27.35 %. Valore vero:  1 indice:  327
# Valore predetto: 0 al  31.79 % mentre 1 al  35.24 % mentre 2 al  32.98 %. Valore vero:  1 indice:  328
# Valore predetto: 0 al  13.65 % mentre 1 al  26.0 % mentre 2 al  60.35 %. Valore vero:  0 indice:  329
# Valore predetto: 0 al  18.43 % mentre 1 al  30.7 % mentre 2 al  50.87 %. Valore vero:  2 indice:  330
# Valore predetto: 0 al  63.2 % mentre 1 al  24.65 % mentre 2 al  12.14 %. Valore vero:  1 indice:  331
# Valore predetto: 0 al  12.5 % mentre 1 al  25.92 % mentre 2 al  61.57 %. Valore vero:  2 indice:  332
# Valore predetto: 0 al  60.04 % mentre 1 al  26.2 % mentre 2 al  13.76 %. Valore vero:  1 indice:  333
# Valore predetto: 0 al  76.87 % mentre 1 al  16.32 % mentre 2 al  6.8 %. Valore vero:  0 indice:  334
# Valore predetto: 0 al  29.84 % mentre 1 al  35.34 % mentre 2 al  34.82 %. Valore vero:  0 indice:  335
# Valore predetto: 0 al  20.68 % mentre 1 al  31.8 % mentre 2 al  47.52 %. Valore vero:  1 indice:  336
# Valore predetto: 0 al  29.26 % mentre 1 al  34.61 % mentre 2 al  36.12 %. Valore vero:  2 indice:  337
# Valore predetto: 0 al  17.76 % mentre 1 al  29.98 % mentre 2 al  52.26 %. Valore vero:  2 indice:  338
# Valore predetto: 0 al  18.37 % mentre 1 al  30.46 % mentre 2 al  51.18 %. Valore vero:  0 indice:  339
# Valore predetto: 0 al  10.79 % mentre 1 al  23.16 % mentre 2 al  66.05 %. Valore vero:  1 indice:  340
# Valore predetto: 0 al  54.07 % mentre 1 al  29.34 % mentre 2 al  16.6 %. Valore vero:  0 indice:  341
# Valore predetto: 0 al  51.86 % mentre 1 al  30.57 % mentre 2 al  17.58 %. Valore vero:  1 indice:  342
# Valore predetto: 0 al  23.04 % mentre 1 al  32.68 % mentre 2 al  44.27 %. Valore vero:  2 indice:  343
# Valore predetto: 0 al  29.15 % mentre 1 al  34.36 % mentre 2 al  36.49 %. Valore vero:  1 indice:  344
# Valore predetto: 0 al  27.4 % mentre 1 al  33.94 % mentre 2 al  38.66 %. Valore vero:  0 indice:  345
# Valore predetto: 0 al  6.96 % mentre 1 al  16.55 % mentre 2 al  76.5 %. Valore vero:  2 indice:  346
# Valore predetto: 0 al  38.23 % mentre 1 al  34.39 % mentre 2 al  27.38 %. Valore vero:  1 indice:  347
# Valore predetto: 0 al  14.62 % mentre 1 al  27.26 % mentre 2 al  58.13 %. Valore vero:  1 indice:  348
# Valore predetto: 0 al  9.05 % mentre 1 al  20.05 % mentre 2 al  70.9 %. Valore vero:  2 indice:  349
# Valore predetto: 0 al  16.02 % mentre 1 al  29.12 % mentre 2 al  54.86 %. Valore vero:  2 indice:  350
# Valore predetto: 0 al  35.42 % mentre 1 al  34.78 % mentre 2 al  29.8 %. Valore vero:  0 indice:  351
# Valore predetto: 0 al  22.46 % mentre 1 al  31.87 % mentre 2 al  45.66 %. Valore vero:  0 indice:  352
# Valore predetto: 0 al  43.82 % mentre 1 al  32.65 % mentre 2 al  23.53 %. Valore vero:  0 indice:  353
# Valore predetto: 0 al  64.26 % mentre 1 al  23.66 % mentre 2 al  12.08 %. Valore vero:  2 indice:  354
# Valore predetto: 0 al  9.96 % mentre 1 al  22.52 % mentre 2 al  67.52 %. Valore vero:  0 indice:  355
# Valore predetto: 0 al  56.38 % mentre 1 al  28.28 % mentre 2 al  15.34 %. Valore vero:  0 indice:  356
# Valore predetto: 0 al  24.6 % mentre 1 al  33.9 % mentre 2 al  41.5 %. Valore vero:  2 indice:  357
# Valore predetto: 0 al  39.06 % mentre 1 al  34.12 % mentre 2 al  26.82 %. Valore vero:  2 indice:  358
# Valore predetto: 0 al  9.28 % mentre 1 al  20.53 % mentre 2 al  70.19 %. Valore vero:  2 indice:  359
# Valore predetto: 0 al  15.66 % mentre 1 al  28.54 % mentre 2 al  55.79 %. Valore vero:  1 indice:  360
# Valore predetto: 0 al  30.27 % mentre 1 al  35.22 % mentre 2 al  34.51 %. Valore vero:  1 indice:  361
# Valore predetto: 0 al  31.74 % mentre 1 al  34.58 % mentre 2 al  33.68 %. Valore vero:  2 indice:  362
# Valore predetto: 0 al  58.87 % mentre 1 al  27.08 % mentre 2 al  14.05 %. Valore vero:  1 indice:  363
# Valore predetto: 0 al  36.98 % mentre 1 al  34.44 % mentre 2 al  28.57 %. Valore vero:  2 indice:  364
# Valore predetto: 0 al  11.89 % mentre 1 al  24.2 % mentre 2 al  63.92 %. Valore vero:  1 indice:  365
# Valore predetto: 0 al  9.1 % mentre 1 al  21.27 % mentre 2 al  69.64 %. Valore vero:  2 indice:  366
# Valore predetto: 0 al  21.3 % mentre 1 al  32.34 % mentre 2 al  46.36 %. Valore vero:  2 indice:  367
# Valore predetto: 0 al  26.64 % mentre 1 al  33.54 % mentre 2 al  39.82 %. Valore vero:  2 indice:  368
# Valore predetto: 0 al  12.37 % mentre 1 al  25.38 % mentre 2 al  62.25 %. Valore vero:  1 indice:  369
# Valore predetto: 0 al  59.96 % mentre 1 al  26.42 % mentre 2 al  13.63 %. Valore vero:  2 indice:  370
# Valore predetto: 0 al  35.05 % mentre 1 al  34.48 % mentre 2 al  30.48 %. Valore vero:  1 indice:  371
# Valore predetto: 0 al  24.02 % mentre 1 al  32.95 % mentre 2 al  43.04 %. Valore vero:  2 indice:  372
# Valore predetto: 0 al  18.15 % mentre 1 al  31.48 % mentre 2 al  50.37 %. Valore vero:  0 indice:  373
# Valore predetto: 0 al  12.64 % mentre 1 al  25.4 % mentre 2 al  61.96 %. Valore vero:  1 indice:  374
# Valore predetto: 0 al  8.34 % mentre 1 al  20.0 % mentre 2 al  71.66 %. Valore vero:  2 indice:  375
# Valore predetto: 0 al  20.96 % mentre 1 al  32.82 % mentre 2 al  46.21 %. Valore vero:  2 indice:  376
# Valore predetto: 0 al  68.05 % mentre 1 al  21.96 % mentre 2 al  9.98 %. Valore vero:  2 indice:  377
# Valore predetto: 0 al  35.83 % mentre 1 al  34.85 % mentre 2 al  29.33 %. Valore vero:  0 indice:  378
# Valore predetto: 0 al  34.04 % mentre 1 al  34.96 % mentre 2 al  31.0 %. Valore vero:  2 indice:  379

# %%
y_pred = []
for i in range(pred2.shape[1]):
  unique, counts = np.unique(pred2[:,i], return_counts=True)
  perc = counts/pred2.shape[0]*100
  y_pred.append(np.argmax(perc))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

cm= confusion_matrix(Y, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

print('Classification Report')
target_names = ["0","1","2"]
print(classification_report(Y, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.55      0.62      0.59       106
#            1       0.32      0.06      0.11       108
#            2       0.54      0.78      0.64       166
#
#     accuracy                           0.53       380
#    macro avg       0.47      0.49      0.45       380
# weighted avg       0.48      0.53      0.47       380

# %%
model_data = {'N': len(Y), 'y': (Y+1).tolist(), 'T': len(Teams), 'R': R, 'R2': R2.values.tolist(), 'IH': init_home, 'IA': init_away}
predictions = ordinal_reg.generate_quantities(model_data, model_fit)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmpx_aj2nu8/mwqhlc6n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=1', 'random', 'seed=78409', 'data', 'file=/tmp/tmpx_aj2nu8/mwqhlc6n.json', 'output', 'file=/tmp/tmpx_aj2nu8/ordinal_regcq56gb1e/ordinal_reg-20230109164936_1.csv', 'method=generate_quantities', 'fitted_params=/tmp/tmpx_aj2nu8/ordinal_regh3rbgcom/ordinal_reg-20230109163941_1.csv']
# 16:49:36 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 16:49:49 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing
# DEBUG:cmdstanpy:idx 1
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=2', 'random', 'seed=78409', 'data', 'file=/tmp/tmpx_aj2nu8/mwqhlc6n.json', 'output', 'file=/tmp/tmpx_aj2nu8/ordinal_regcq56gb1e/ordinal_reg-20230109164936_2.csv', 'method=generate_quantities', 'fitted_params=/tmp/tmpx_aj2nu8/ordinal_regh3rbgcom/ordinal_reg-20230109163941_2.csv']
# 16:49:49 - cmdstanpy - INFO - Chain [2] start processing
# INFO:cmdstanpy:Chain [2] start processing
# 16:50:01 - cmdstanpy - INFO - Chain [2] done processing
# INFO:cmdstanpy:Chain [2] done processing
# DEBUG:cmdstanpy:idx 2
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=3', 'random', 'seed=78409', 'data', 'file=/tmp/tmpx_aj2nu8/mwqhlc6n.json', 'output', 'file=/tmp/tmpx_aj2nu8/ordinal_regcq56gb1e/ordinal_reg-20230109164936_3.csv', 'method=generate_quantities', 'fitted_params=/tmp/tmpx_aj2nu8/ordinal_regh3rbgcom/ordinal_reg-20230109163941_3.csv']
# 16:50:01 - cmdstanpy - INFO - Chain [3] start processing
# INFO:cmdstanpy:Chain [3] start processing
# 16:50:14 - cmdstanpy - INFO - Chain [3] done processing
# INFO:cmdstanpy:Chain [3] done processing
# DEBUG:cmdstanpy:idx 3
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/ordinal_reg', 'id=4', 'random', 'seed=78409', 'data', 'file=/tmp/tmpx_aj2nu8/mwqhlc6n.json', 'output', 'file=/tmp/tmpx_aj2nu8/ordinal_regcq56gb1e/ordinal_reg-20230109164936_4.csv', 'method=generate_quantities', 'fitted_params=/tmp/tmpx_aj2nu8/ordinal_regh3rbgcom/ordinal_reg-20230109163941_4.csv']
# 16:50:14 - cmdstanpy - INFO - Chain [4] start processing
# INFO:cmdstanpy:Chain [4] start processing
# 16:50:27 - cmdstanpy - INFO - Chain [4] done processing
# INFO:cmdstanpy:Chain [4] done processing

# %%
pred.shape
# Out:
# (20000, 380)

# %%
pred = predictions.y_pred
m=0
for i in range(pred.shape[0]):
  if m < sum(pred[i] == Y+1):
    m = sum(pred[i] == Y+1)
    idx = i

# %%
print(m,idx)
# Out:
# 197 10801
