# %%
from cmdstanpy import cmdstan_path, CmdStanModel

import arviz as az
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

from tensorflow_probability.substrates import numpy as tfp
tfd = tfp.distributions

# %%
import cmdstanpy
cmdstanpy.install_cmdstan()
a=cmdstan_path()
# Out:
# Installing CmdStan version: 2.31.0
# Install directory: /root/.cmdstan
# Downloading CmdStan version 2.31.0
# Download successful, file: /tmp/tmpjbmzxch4
# Extracting distribution
# DEBUG:cmdstanpy:cmd: make build -j1
# cwd: None
# Unpacked download as cmdstan-2.31.0
# Building version cmdstan-2.31.0, may take several minutes, depending on your system.
# DEBUG:cmdstanpy:cmd: make examples/bernoulli/bernoulli
# cwd: None
# Test model compilation
# Installed cmdstan-2.31.0

# %%
# Importing 2018-19 season results
#X = pd.read_excel("/Users/alessandropreti/jupyter/progetto bayesian /data/SerieA_basket.xlsx", sheet_name = "Stagione 2018-19")
X = pd.read_excel("SerieA_basket.xlsx", sheet_name = "Stagione 2018-19")
cols = X.columns
X.head()
# Out:
#                Date                       Team  PTS  \
# 0  Sat, Oct 6, 2018          Red October Cantù   81
# 1  Sat, Oct 6, 2018             Vanoli Cremona  104
# 2  Sun, Oct 7, 2018        Happy Casa Brindisi   92
# 3  Sun, Oct 7, 2018             OriOra Pistoia   77
# 4  Sun, Oct 7, 2018  Banco di Sardegna Sassari   77
#
#                          Opp  PTS2
# 0           Sidigas Avellino    98
# 1  Dolomiti Energia Trentino    99
# 2  AX Armani Exchange Milano   103
# 3                  VL Pesaro    83
# 4  Grissin Bon Reggio Emilia    85

# %%
# Importing 2018-19 season results (used for skill parameters initialization)
#X_old = pd.read_excel("/Users/alessandropreti/jupyter/progetto bayesian /data/SerieA_basket.xlsx", sheet_name = "Stagione 2017-18")
X_old = pd.read_excel("SerieA_basket.xlsx", sheet_name = "Stagione 2017-18")
cols_old = X.columns
X_old.head()
# Out:
#                 Date                       Team  PTS  \
# 0  Sat, Sep 30, 2017   Virtus Segafredo Bologna   74
# 1   Sun, Oct 1, 2017                FIAT Torino   72
# 2   Sun, Oct 1, 2017  EA7 Emporio Armani Milano   76
# 3   Sun, Oct 1, 2017     Germani Basket Brescia   73
# 4   Sun, Oct 1, 2017          Red October Cantù   80
#
#                          Opp  PTS2
# 0  Dolomiti Energia Trentino    78
# 1        Happy Casa Brindisi    67
# 2             Vanoli Cremona    60
# 3                  VL Pesaro    70
# 4  Banco di Sardegna Sassari    94

# %%
Y = np.array([1 if(X.iloc[i,2]-X.iloc[i,4]>0) else(0) for i in range(X.shape[0])])
X['Y']=Y.tolist()
X.head()
# Out:
#                Date                       Team  PTS  \
# 0  Sat, Oct 6, 2018          Red October Cantù   81
# 1  Sat, Oct 6, 2018             Vanoli Cremona  104
# 2  Sun, Oct 7, 2018        Happy Casa Brindisi   92
# 3  Sun, Oct 7, 2018             OriOra Pistoia   77
# 4  Sun, Oct 7, 2018  Banco di Sardegna Sassari   77
#
#                          Opp  PTS2  Y
# 0           Sidigas Avellino    98  0
# 1  Dolomiti Energia Trentino    99  1
# 2  AX Armani Exchange Milano   103  0
# 3                  VL Pesaro    83  0
# 4  Grissin Bon Reggio Emilia    85  0

# %%
Y_old = np.array([1 if(X_old.iloc[i,2]-X_old.iloc[i,4]>0) else(0) for i in range(X_old.shape[0])])
X_old['Y']=Y_old.tolist()
X_old.head()
# Out:
#                 Date                       Team  PTS  \
# 0  Sat, Sep 30, 2017   Virtus Segafredo Bologna   74
# 1   Sun, Oct 1, 2017                FIAT Torino   72
# 2   Sun, Oct 1, 2017  EA7 Emporio Armani Milano   76
# 3   Sun, Oct 1, 2017     Germani Basket Brescia   73
# 4   Sun, Oct 1, 2017          Red October Cantù   80
#
#                          Opp  PTS2  Y
# 0  Dolomiti Energia Trentino    78  0
# 1        Happy Casa Brindisi    67  1
# 2             Vanoli Cremona    60  1
# 3                  VL Pesaro    70  1
# 4  Banco di Sardegna Sassari    94  0

# %%
plt.hist(Y, bins=[-0.5, 0.5, 1.5], align='mid', rwidth=0.5)
plt.xticks([0, 1])
plt.title('Histogram of results')
plt.savefig('histbasket')

# %%
plt.hist(X.iloc[:,2])
# Out:
# (array([  1.,   0.,   0.,   0.,  11.,  65., 107.,  71.,  13.,   4.]),
#  array([  0. ,  12.2,  24.4,  36.6,  48.8,  61. ,  73.2,  85.4,  97.6,
#         109.8, 122. ]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(X.iloc[:,4])
# Out:
# (array([ 1.,  0.,  0.,  1., 17., 57., 96., 50., 36., 14.]),
#  array([ 20. ,  29.5,  39. ,  48.5,  58. ,  67.5,  77. ,  86.5,  96. ,
#         105.5, 115. ]),
#  <a list of 10 Patch objects>)

# %%
Teams_old=list(X_old.iloc[:,1].unique())
Teams_old=sorted(Teams_old)

# %%
Teams=list(X.iloc[:,1].unique())
Teams=sorted(Teams)
#len(Teams)

# %%
Teams_old
# Out:
# ['Banco di Sardegna Sassari',
#  "Betaland Capo d'Orlando",
#  'Dolomiti Energia Trentino',
#  'EA7 Emporio Armani Milano',
#  'FIAT Torino',
#  'Germani Basket Brescia',
#  'Grissin Bon Reggio Emilia',
#  'Happy Casa Brindisi',
#  'Openjobmetis Varese',
#  'Red October Cantù',
#  'Sidigas Avellino',
#  'The Flexx Pistoia',
#  'Umana Reyer Venezia',
#  'VL Pesaro',
#  'Vanoli Cremona',
#  'Virtus Segafredo Bologna']

# %%
Teams
# Out:
# ['AX Armani Exchange Milano',
#  'Alma Pallacanestro Trieste',
#  'Banco di Sardegna Sassari',
#  'Dolomiti Energia Trentino',
#  'FIAT Torino',
#  'Germani Basket Brescia',
#  'Grissin Bon Reggio Emilia',
#  'Happy Casa Brindisi',
#  'Openjobmetis Varese',
#  'OriOra Pistoia',
#  'Red October Cantù',
#  'Sidigas Avellino',
#  'Umana Reyer Venezia',
#  'VL Pesaro',
#  'Vanoli Cremona',
#  'Virtus Segafredo Bologna']

# %% [markdown]
# #### Note on teams:
#
# Between the two seasons:
#
# 1.   Armani Milano changed name
# 2.   Pistoia changed name as well
# 3.   Betaland Capo D'Orlando was demoted, his skill rate will be given to Alma Pallacanestro Trieste wich was newly promoted

# %%
X_old.loc[X_old.Team == 'EA7 Emporio Armani Milano', 'Team'] = 'AX Armani Exchange Milano'
X_old.loc[X_old.Opp == 'EA7 Emporio Armani Milano', 'Opp'] = 'AX Armani Exchange Milano'

X_old.loc[X_old.Team == 'The Flexx Pistoia', 'Team'] = 'OriOra Pistoia'
X_old.loc[X_old.Opp == 'The Flexx Pistoia', 'Opp'] = 'OriOra Pistoia'

X_old.loc[X_old.Team == "Betaland Capo d'Orlando", 'Team'] = 'Alma Pallacanestro Trieste'
X_old.loc[X_old.Opp == "Betaland Capo d'Orlando", 'Opp'] = 'Alma Pallacanestro Trieste'

Teams_old=list(X_old.iloc[:,1].unique())
Teams_old=sorted(Teams_old)

# %%
Teams == Teams_old
# Out:
# True

# %%
X['Team'].value_counts()
# Out:
# Umana Reyer Venezia           23
# Banco di Sardegna Sassari     22
# Vanoli Cremona                19
# Dolomiti Energia Trentino     18
# Sidigas Avellino              18
# AX Armani Exchange Milano     18
# Happy Casa Brindisi           17
# Alma Pallacanestro Trieste    17
# Red October Cantù             15
# OriOra Pistoia                15
# Virtus Segafredo Bologna      15
# Germani Basket Brescia        15
# FIAT Torino                   15
# Grissin Bon Reggio Emilia     15
# VL Pesaro                     15
# Openjobmetis Varese           15
# Name: Team, dtype: int64

# %%
X['Opp'].value_counts()
# Out:
# Umana Reyer Venezia           24
# Banco di Sardegna Sassari     21
# AX Armani Exchange Milano     20
# Vanoli Cremona                20
# Sidigas Avellino              17
# Dolomiti Energia Trentino     17
# Alma Pallacanestro Trieste    17
# Happy Casa Brindisi           16
# VL Pesaro                     15
# Grissin Bon Reggio Emilia     15
# Openjobmetis Varese           15
# FIAT Torino                   15
# Germani Basket Brescia        15
# Red October Cantù             15
# OriOra Pistoia                15
# Virtus Segafredo Bologna      15
# Name: Opp, dtype: int64

# %%
max(X['Opp'].value_counts())
# Out:
# 24

# %%
len(Teams)
# Out:
# 16

# %%
def names_to_index(Teams):

    """
    Creates a dictionary that associates teams to number
    """
    # dictionary comprehension
    d = {index: value for value, index in enumerate(Teams)}

    return d

# %%
def crea_matrici(X):
    """
    Takes as input a matrix X and their result to create two additional matrices that can be used for our model
    """
    #matrice casa trasferta risultato in numeri (N_match, 3)
    Y = np.array([1 if(X.iloc[i,2]-X.iloc[i,4]>0) else(0) for i in range(X.shape[0])])
    
    Teams=list(X.iloc[:,1].unique())
    Teams=sorted(Teams)
    d = names_to_index(Teams)
    
    T_1 = np.array([d[X.iloc[i,1]] for i in range(X.shape[0])])
    T_2 = np.array([d[X.iloc[i,3]] for i in range(X.shape[0])])
    R = pd.DataFrame({"Home":T_1,"Away":T_2,"Result":Y})
    
    #matrice di storie delle squadre, casa-trasferta (N_Teams, 2)
    dim_vec_home = R['Home'].value_counts()
    dim_vec_away = R['Away'].value_counts()
    
    R2 = pd.DataFrame(index = sorted(np.unique(T_1)), columns = ["Home", "Away"])
    
    for i in range(len(np.unique(T_1))):
        R2["Home"][i] = np.empty(0,dtype = np.int8)
        R2["Away"][i] = np.empty(0,dtype = np.int8)
        
    for i in range(len(T_1)):
        h = R["Home"][i]
        a = R["Away"][i]
        R2["Home"][h] = np.append(R2["Home"][h],R["Result"][i])
        R2["Away"][a] = np.append(R2["Away"][a], 1 - R["Result"][i])
    m=max(max(X['Opp'].value_counts()),max(X['Team'].value_counts()))
    print('The length of the array is: ',m)
    for i in range(R2.shape[0]):
      while(len(R2["Home"][i])<m):
        R2["Home"][i]=np.append(R2["Home"][i],0)
      while(len(R2["Away"][i])<m):
        R2["Away"][i]=np.append(R2["Away"][i],0)
    
    
    return R,R2

# %%
def compute_skills(R,R2,init_home,init_away):
    """
    Takes as inputs a matrix X with teams and their result
    init is the inizialization of the skills, must be an array or list with the skill for each team.

    Returns two matrices with home and away skills parameters by team 
    and one matrix with skills parameters oredered cronologically
    """
    import numpy as np
    import pandas as pd

    N=R.shape[0] # number of matches
    
    #Lambda initialization
    l1 = 0.5
    l2 = 0.5

    #Creating matrices to store the skill parameters and their stories
        
    HS = pd.DataFrame(index = R2.index, columns = ["Home", "Away"])
    
    for i in range(R2.shape[0]):
        HS["Home"][i] = np.empty(0)
        HS["Away"][i] = np.empty(0)
        
    data = pd.DataFrame(index = R.index, columns=['Home','Away'])
    C = pd.DataFrame({"Home": np.zeros(len(R2.index), dtype = np.int8), "Away": np.zeros(len(R2.index), dtype = np.int8)})
    
    for i in range(R.shape[0]):
        h = R["Home"][i]
        a = R["Away"][i]

    # HOME SKILL
        if(C["Home"][h]==0):
          xh = init_home[h]
        else:
          #calcolo somma per xh
          sh = 0
          for j in range(C["Home"][h]):
              sh = sh + R2["Home"][h][j]*(1-l1)**j
        
          xh = l1*sh + init_home[h]*(1-l1)**C["Home"][h]

     # AWAY SKILL       
        if(C["Away"][a]==0):
          xv = init_away[a]
        else:
          #calcolo somma per xv
          sa = 0
          for j in range(C["Away"][a]):
             sa = sa + R2["Away"][a][j]*(1-l2)**j
        
          xv = l2*sa + init_away[a]*(1-l2)**C["Away"][a]
        
        #append nostra matrice storico e dati per stan
        HS["Home"][h] = np.append(HS["Home"][h],round(xh,3))
        HS["Away"][a] = np.append(HS["Away"][a],round(xv,3))
        data["Home"][i] = round(xh,3)
        data["Away"][i] = round(xv,3)
        
        #incremento counts
        C["Home"][h] += 1
        C["Away"][a] += 1

    
    return HS,data

# %%
R_old, R2_old = crea_matrici(X_old)
HS_old, data_old = compute_skills(R_old, R2_old, 0.5*np.ones(len(Teams)), 0.5*np.ones(len(Teams)))

plt.plot(HS_old["Home"][0])
# Out:
# The length of the array is:  23

# %%
init_home = np.empty(0)
init_away = np.empty(0)

for i in range(HS_old.shape[0]):
  init_home = np.append(init_home,HS_old["Home"][i][-1])
  init_away = np.append(init_away,HS_old["Away"][i][-1])

R,R2 = crea_matrici(X)
# Out:
# The length of the array is:  24

# %%
logit_reg='''

data{    
    int<lower=0> N; // Matches
    array[N] int y;
    int<lower=0> T; // Teams
    array[N,3] int R;  // Game+Result matrix
    array[T,2,24] int R2; // Teams' history
    vector[T] IH;    // init_home
    vector[T] IA;    // init_away
}


parameters{
    real mu0;
    real sigma0;
    vector[2] beta;
    real int_raw;
    real<lower=0,upper=1> l1;
    real<lower=0,upper=1> l2;
}

transformed parameters{
  matrix[N,2] X;     // Skills
  real sh;
  real sa;
  vector[N] mu;
  real intercept;
  {
  array[T,2] int C=rep_array(0,T,2);

  for(i in 1:N){
    int h = R[i,1]+1; // Home team index
    int a = R[i,2]+1; // Away team index
    int ch = C[h,1]; // Home count
    int ca = C[a,2]; //Away count

    // Home team skill update
    if(ch==0){
      X[i,1] = IH[h];
    }
    else{
      sh=0;
      for(j in 1:ch){   
        sh=sh+R2[h,1,j]*pow((1-l1),j);
        }
      X[i,1]=l1*sh+IH[h]*pow((1-l1),ch);
    }

    // Away team skill update
    if(ca==0){
      X[i,2] = IA[a];
    }
    else{
      sa=0;
      for(j in 1:ca){   
        sa=sa+R2[a,2,j]*pow((1-l2),j);
      }
      X[i,2]=l2*sa+IA[a]*pow((1-l2),ca);
    }

    // Count update
    C[h,1]=C[h,1]+1;
    C[a,2]=C[a,2]+1;

    mu[i] = row(X, i) * beta;
  }
  intercept = mu0 + int_raw * sigma0;
  }
}

model{
    mu0 ~ normal(0, 1./10);
    sigma0 ~ inv_gamma(0.1, 1/0.01);

    int_raw ~ normal(0,1);
    
    beta[1] ~ normal(0,3);
    beta[2] ~ normal(0,3);
    

    l1 ~ beta(2,2);
    l1 ~ beta(2,2);

    for (i in 1:N){
        y[i] ~ bernoulli_logit(intercept + mu[i]);
   }
}

generated quantities{
  vector[N] y_pred; 
  for(i in 1:N){
    y_pred[i] = bernoulli_logit_rng(intercept + mu[i]);
  }
}
'''

stan_file = "./logit.stan"

with open(stan_file, "w") as f:
    print(logit_reg, file=f)

logit_reg = CmdStanModel(stan_file=stan_file)
# Out:
# 20:25:26 - cmdstanpy - INFO - compiling stan file /content/logit.stan to exe file /content/logit
# INFO:cmdstanpy:compiling stan file /content/logit.stan to exe file /content/logit
# DEBUG:cmdstanpy:cmd: make /content/logit
# cwd: /root/.cmdstan/cmdstan-2.31.0
# DEBUG:cmdstanpy:Console output:
#
# --- Translating Stan model to C++ code ---
# bin/stanc  --o=/content/logit.hpp /content/logit.stan
#
# --- Compiling, linking C++ code ---
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I stan/lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.78.0 -I stan/lib/stan_math/lib/sundials_6.1.1/include -I stan/lib/stan_math/lib/sundials_6.1.1/src/sundials    -DBOOST_DISABLE_ASSERTS          -c -Wno-ignored-attributes   -x c++ -o /content/logit.o /content/logit.hpp
# g++ -std=c++1y -pthread -D_REENTRANT -Wno-sign-compare -Wno-ignored-attributes      -I stan/lib/stan_math/lib/tbb_2020.3/include    -O3 -I src -I stan/src -I stan/lib/rapidjson_1.1.0/ -I lib/CLI11-1.9.1/ -I stan/lib/stan_math/ -I stan/lib/stan_math/lib/eigen_3.3.9 -I stan/lib/stan_math/lib/boost_1.78.0 -I stan/lib/stan_math/lib/sundials_6.1.1/include -I stan/lib/stan_math/lib/sundials_6.1.1/src/sundials    -DBOOST_DISABLE_ASSERTS                -Wl,-L,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb"      /content/logit.o src/cmdstan/main.o        -Wl,-L,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb" -Wl,-rpath,"/root/.cmdstan/cmdstan-2.31.0/stan/lib/stan_math/lib/tbb"   stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_nvecserial.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_cvodes.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_idas.a stan/lib/stan_math/lib/sundials_6.1.1/lib/libsundials_kinsol.a  stan/lib/stan_math/lib/tbb/libtbb.so.2 -o /content/logit
# rm -f /content/logit.o
#
# 20:25:42 - cmdstanpy - INFO - compiled model executable: /content/logit
# INFO:cmdstanpy:compiled model executable: /content/logit

# %%
model_data = {'N': len(Y), 'y': Y, 'T': len(Teams), 'R': R, 'R2': R2.values.tolist(), 'IH': init_home, 'IA': init_away}

model_fit=logit_reg.sample(data=model_data, chains=4,
                           parallel_chains=4, iter_warmup=1000,
                           iter_sampling=5000, adapt_delta=0.999,
                           step_size = 0.5, max_treedepth = 15)
#model_fit=logit_reg.sample(data=model_data, chains=4, parallel_chains=4, iter_warmup=1000,iter_sampling=2000)
model_data=az.from_cmdstanpy(model_fit)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmptxytpbcl/iwsikhra.json
# DEBUG:cmdstanpy:cmd: /content/logit info
# cwd: None
# 20:25:42 - cmdstanpy - INFO - CmdStan start processing
# INFO:cmdstanpy:CmdStan start processing
# chain 1 |          | 00:00 Status
# chain 2 |          | 00:00 Status
# chain 3 |          | 00:00 Status
# chain 4 |          | 00:00 Status
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/logit', 'id=1', 'random', 'seed=70877', 'data', 'file=/tmp/tmptxytpbcl/iwsikhra.json', 'output', 'file=/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_1.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'engine=nuts', 'max_depth=15', 'stepsize=0.5', 'adapt', 'engaged=1', 'delta=0.999']
# DEBUG:cmdstanpy:idx 1
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/logit', 'id=2', 'random', 'seed=70877', 'data', 'file=/tmp/tmptxytpbcl/iwsikhra.json', 'output', 'file=/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_2.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'engine=nuts', 'max_depth=15', 'stepsize=0.5', 'adapt', 'engaged=1', 'delta=0.999']
# DEBUG:cmdstanpy:idx 2
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/logit', 'id=3', 'random', 'seed=70877', 'data', 'file=/tmp/tmptxytpbcl/iwsikhra.json', 'output', 'file=/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_3.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'engine=nuts', 'max_depth=15', 'stepsize=0.5', 'adapt', 'engaged=1', 'delta=0.999']
# DEBUG:cmdstanpy:idx 3
# DEBUG:cmdstanpy:running CmdStan, num_threads: 1
# DEBUG:cmdstanpy:CmdStan args: ['/content/logit', 'id=4', 'random', 'seed=70877', 'data', 'file=/tmp/tmptxytpbcl/iwsikhra.json', 'output', 'file=/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_4.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'engine=nuts', 'max_depth=15', 'stepsize=0.5', 'adapt', 'engaged=1', 'delta=0.999']
# 21:59:48 - cmdstanpy - INFO - CmdStan done processing.
# INFO:cmdstanpy:CmdStan done processing.
# DEBUG:cmdstanpy:runset
# RunSet: chains=4, chain_ids=[1, 2, 3, 4], num_processes=4
#  cmd (chain 1):
# 	['/content/logit', 'id=1', 'random', 'seed=70877', 'data', 'file=/tmp/tmptxytpbcl/iwsikhra.json', 'output', 'file=/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_1.csv', 'method=sample', 'num_samples=5000', 'num_warmup=1000', 'algorithm=hmc', 'engine=nuts', 'max_depth=15', 'stepsize=0.5', 'adapt', 'engaged=1', 'delta=0.999']
#  retcodes=[0, 0, 0, 0]
#  per-chain output files (showing chain 1 only):
#  csv_file:
# 	/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_1.csv
#  console_msgs (if any):
# 	/tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_0-stdout.txt
# DEBUG:cmdstanpy:Chain 1 console:
# method = sample (Default)
#   sample
#     num_samples = 5000
#     num_warmup = 1000 (Default)
#     save_warmup = 0 (Default)
#     thin = 1 (Default)
#     adapt
#       engaged = 1 (Default)
#       gamma = 0.050000000000000003 (Default)
#       delta = 0.999
#       kappa = 0.75 (Default)
#       t0 = 10 (Default)
#       init_buffer = 75 (Default)
#       term_buffer = 50 (Default)
#       window = 25 (Default)
#     algorithm = hmc (Default)
#       hmc
#         engine = nuts (Default)
#           nuts
#             max_depth = 15
#         metric = diag_e (Default)
#         metric_file =  (Default)
#         stepsize = 0.5
#         stepsize_jitter = 0 (Default)
#     num_chains = 1 (Default)
# id = 1 (Default)
# data
#   file = /tmp/tmptxytpbcl/iwsikhra.json
# init = 2 (Default)
# random
#   seed = 70877
# output
#   file = /tmp/tmptxytpbcl/logitskgrmiog/logit-20230127202542_1.csv
#   diagnostic_file =  (Default)
#   refresh = 100 (Default)
#   sig_figs = -1 (Default)
#   profile_file = profile.csv (Default)
# num_threads = 1 (Default)
#
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
# Rejecting initial value:
#   Log probability evaluates to log(0), i.e. negative infinity.
#   Stan can't start sampling from this initial value.
#
# Gradient evaluation took 0.001633 seconds
# 1000 transitions using 10 leapfrog steps per transition would take 16.33 seconds.
# Adjust your expectations accordingly!
#
#
# Iteration:    1 / 6000 [  0%]  (Warmup)
# Iteration:  100 / 6000 [  1%]  (Warmup)
# Iteration:  200 / 6000 [  3%]  (Warmup)
# Iteration:  300 / 6000 [  5%]  (Warmup)
# Iteration:  400 / 6000 [  6%]  (Warmup)
# Iteration:  500 / 6000 [  8%]  (Warmup)
# Iteration:  600 / 6000 [ 10%]  (Warmup)
# Iteration:  700 / 6000 [ 11%]  (Warmup)
# Iteration:  800 / 6000 [ 13%]  (Warmup)
# Iteration:  900 / 6000 [ 15%]  (Warmup)
# Iteration: 1000 / 6000 [ 16%]  (Warmup)
# Iteration: 1001 / 6000 [ 16%]  (Sampling)
# Iteration: 1100 / 6000 [ 18%]  (Sampling)
# Iteration: 1200 / 6000 [ 20%]  (Sampling)
# Iteration: 1300 / 6000 [ 21%]  (Sampling)
# Iteration: 1400 / 6000 [ 23%]  (Sampling)
# Iteration: 1500 / 6000 [ 25%]  (Sampling)
# Iteration: 1600 / 6000 [ 26%]  (Sampling)
# Iteration: 1700 / 6000 [ 28%]  (Sampling)
# Iteration: 1800 / 6000 [ 30%]  (Sampling)
# Iteration: 1900 / 6000 [ 31%]  (Sampling)
# Iteration: 2000 / 6000 [ 33%]  (Sampling)
# Iteration: 2100 / 6000 [ 35%]  (Sampling)
# Iteration: 2200 / 6000 [ 36%]  (Sampling)
# Iteration: 2300 / 6000 [ 38%]  (Sampling)
# Iteration: 2400 / 6000 [ 40%]  (Sampling)
# Iteration: 2500 / 6000 [ 41%]  (Sampling)
# Iteration: 2600 / 6000 [ 43%]  (Sampling)
# Iteration: 2700 / 6000 [ 45%]  (Sampling)
# Iteration: 2800 / 6000 [ 46%]  (Sampling)
# Iteration: 2900 / 6000 [ 48%]  (Sampling)
# Iteration: 3000 / 6000 [ 50%]  (Sampling)
# Iteration: 3100 / 6000 [ 51%]  (Sampling)
# Iteration: 3200 / 6000 [ 53%]  (Sampling)
# Iteration: 3300 / 6000 [ 55%]  (Sampling)
# Iteration: 3400 / 6000 [ 56%]  (Sampling)
# Iteration: 3500 / 6000 [ 58%]  (Sampling)
# Iteration: 3600 / 6000 [ 60%]  (Sampling)
# Iteration: 3700 / 6000 [ 61%]  (Sampling)
# Iteration: 3800 / 6000 [ 63%]  (Sampling)
# Iteration: 3900 / 6000 [ 65%]  (Sampling)
# Iteration: 4000 / 6000 [ 66%]  (Sampling)
# Iteration: 4100 / 6000 [ 68%]  (Sampling)
# Iteration: 4200 / 6000 [ 70%]  (Sampling)
# Iteration: 4300 / 6000 [ 71%]  (Sampling)
# Iteration: 4400 / 6000 [ 73%]  (Sampling)
# Iteration: 4500 / 6000 [ 75%]  (Sampling)
# Iteration: 4600 / 6000 [ 76%]  (Sampling)
# Iteration: 4700 / 6000 [ 78%]  (Sampling)
# Iteration: 4800 / 6000 [ 80%]  (Sampling)
# Iteration: 4900 / 6000 [ 81%]  (Sampling)
# Iteration: 5000 / 6000 [ 83%]  (Sampling)
# Iteration: 5100 / 6000 [ 85%]  (Sampling)
# Iteration: 5200 / 6000 [ 86%]  (Sampling)
# Iteration: 5300 / 6000 [ 88%]  (Sampling)
# Iteration: 5400 / 6000 [ 90%]  (Sampling)
# Iteration: 5500 / 6000 [ 91%]  (Sampling)
# Iteration: 5600 / 6000 [ 93%]  (Sampling)
# Iteration: 5700 / 6000 [ 95%]  (Sampling)
# Iteration: 5800 / 6000 [ 96%]  (Sampling)
# Iteration: 5900 / 6000 [ 98%]  (Sampling)
# Iteration: 6000 / 6000 [100%]  (Sampling)
#
#  Elapsed Time: 1758.93 seconds (Warm-up)
#                2228.3 seconds (Sampling)
#                3987.23 seconds (Total)
# 21:59:49 - cmdstanpy - WARNING - Some chains may have failed to converge.
# 	Chain 1 had 1 divergent transitions (0.0%)
# 	Chain 3 had 2 divergent transitions (0.0%)
# 	Chain 4 had 1 divergent transitions (0.0%)
# 	Use function "diagnose()" to see further information.
# WARNING:cmdstanpy:Some chains may have failed to converge.
# 	Chain 1 had 1 divergent transitions (0.0%)
# 	Chain 3 had 2 divergent transitions (0.0%)
# 	Chain 4 had 1 divergent transitions (0.0%)
# 	Use function "diagnose()" to see further information.

# %%
cmdstanpy_data = az.from_cmdstanpy(model_fit)
np.sum(cmdstanpy_data.sample_stats.diverging)
# Out:
# <xarray.DataArray 'diverging' ()>
# array(4)

# %%
az.plot_trace(model_data, var_names=["intercept","beta", "sigma0","l1","l2"], compact=False)
plt.tight_layout()
plt.show()

# %%
pred = model_fit.y_pred
m=0
for i in range(pred.shape[0]):
  if m < sum(pred[i] == Y):
    m = sum(pred[i] == Y)
    idx = i

# %%
print(m,idx)
# Out:
# 180 11286

# %%
for i in range(pred.shape[1]):
  unique, counts = np.unique(pred[:,i], return_counts=True)
  perc = counts/pred.shape[0]*100
  print("Valore predetto: 0 al ",round(perc[0],2),"% mentre 1 al ",round(perc[1],2),"%. Valore vero: ", Y[i])
# Out:
# Valore predetto: 0 al  78.96 % mentre 1 al  21.04 %. Valore vero:  0
# Valore predetto: 0 al  72.44 % mentre 1 al  27.56 %. Valore vero:  1
# Valore predetto: 0 al  80.08 % mentre 1 al  19.92 %. Valore vero:  0
# Valore predetto: 0 al  44.52 % mentre 1 al  55.48 %. Valore vero:  0
# Valore predetto: 0 al  62.4 % mentre 1 al  37.6 %. Valore vero:  0
# Valore predetto: 0 al  53.39 % mentre 1 al  46.62 %. Valore vero:  1
# Valore predetto: 0 al  38.04 % mentre 1 al  61.96 %. Valore vero:  0
# Valore predetto: 0 al  58.37 % mentre 1 al  41.63 %. Valore vero:  0
# Valore predetto: 0 al  70.7 % mentre 1 al  29.3 %. Valore vero:  0
# Valore predetto: 0 al  79.54 % mentre 1 al  20.46 %. Valore vero:  0
# Valore predetto: 0 al  45.02 % mentre 1 al  54.98 %. Valore vero:  0
# Valore predetto: 0 al  77.4 % mentre 1 al  22.6 %. Valore vero:  0
# Valore predetto: 0 al  60.3 % mentre 1 al  39.7 %. Valore vero:  0
# Valore predetto: 0 al  42.16 % mentre 1 al  57.84 %. Valore vero:  1
# Valore predetto: 0 al  79.9 % mentre 1 al  20.1 %. Valore vero:  0
# Valore predetto: 0 al  51.12 % mentre 1 al  48.88 %. Valore vero:  1
# Valore predetto: 0 al  67.94 % mentre 1 al  32.06 %. Valore vero:  1
# Valore predetto: 0 al  63.07 % mentre 1 al  36.93 %. Valore vero:  1
# Valore predetto: 0 al  64.54 % mentre 1 al  35.46 %. Valore vero:  1
# Valore predetto: 0 al  67.3 % mentre 1 al  32.7 %. Valore vero:  0
# Valore predetto: 0 al  55.16 % mentre 1 al  44.84 %. Valore vero:  1
# Valore predetto: 0 al  45.6 % mentre 1 al  54.4 %. Valore vero:  0
# Valore predetto: 0 al  68.73 % mentre 1 al  31.27 %. Valore vero:  0
# Valore predetto: 0 al  66.78 % mentre 1 al  33.22 %. Valore vero:  0
# Valore predetto: 0 al  70.1 % mentre 1 al  29.9 %. Valore vero:  1
# Valore predetto: 0 al  44.1 % mentre 1 al  55.9 %. Valore vero:  1
# Valore predetto: 0 al  72.57 % mentre 1 al  27.43 %. Valore vero:  0
# Valore predetto: 0 al  43.15 % mentre 1 al  56.85 %. Valore vero:  1
# Valore predetto: 0 al  67.13 % mentre 1 al  32.87 %. Valore vero:  1
# Valore predetto: 0 al  66.24 % mentre 1 al  33.76 %. Valore vero:  0
# Valore predetto: 0 al  64.32 % mentre 1 al  35.68 %. Valore vero:  0
# Valore predetto: 0 al  59.5 % mentre 1 al  40.51 %. Valore vero:  1
# Valore predetto: 0 al  71.09 % mentre 1 al  28.91 %. Valore vero:  0
# Valore predetto: 0 al  67.96 % mentre 1 al  32.04 %. Valore vero:  0
# Valore predetto: 0 al  60.98 % mentre 1 al  39.02 %. Valore vero:  0
# Valore predetto: 0 al  63.22 % mentre 1 al  36.79 %. Valore vero:  0
# Valore predetto: 0 al  65.8 % mentre 1 al  34.2 %. Valore vero:  0
# Valore predetto: 0 al  59.62 % mentre 1 al  40.38 %. Valore vero:  0
# Valore predetto: 0 al  55.5 % mentre 1 al  44.5 %. Valore vero:  1
# Valore predetto: 0 al  58.76 % mentre 1 al  41.24 %. Valore vero:  0
# Valore predetto: 0 al  52.9 % mentre 1 al  47.1 %. Valore vero:  1
# Valore predetto: 0 al  57.28 % mentre 1 al  42.72 %. Valore vero:  0
# Valore predetto: 0 al  71.96 % mentre 1 al  28.04 %. Valore vero:  0
# Valore predetto: 0 al  52.09 % mentre 1 al  47.91 %. Valore vero:  1
# Valore predetto: 0 al  67.42 % mentre 1 al  32.58 %. Valore vero:  1
# Valore predetto: 0 al  63.57 % mentre 1 al  36.43 %. Valore vero:  1
# Valore predetto: 0 al  62.6 % mentre 1 al  37.4 %. Valore vero:  0
# Valore predetto: 0 al  62.63 % mentre 1 al  37.37 %. Valore vero:  0
# Valore predetto: 0 al  64.51 % mentre 1 al  35.49 %. Valore vero:  0
# Valore predetto: 0 al  62.28 % mentre 1 al  37.71 %. Valore vero:  0
# Valore predetto: 0 al  68.41 % mentre 1 al  31.59 %. Valore vero:  1
# Valore predetto: 0 al  59.58 % mentre 1 al  40.42 %. Valore vero:  1
# Valore predetto: 0 al  69.36 % mentre 1 al  30.64 %. Valore vero:  1
# Valore predetto: 0 al  53.94 % mentre 1 al  46.06 %. Valore vero:  1
# Valore predetto: 0 al  59.32 % mentre 1 al  40.68 %. Valore vero:  0
# Valore predetto: 0 al  69.98 % mentre 1 al  30.02 %. Valore vero:  1
# Valore predetto: 0 al  64.17 % mentre 1 al  35.83 %. Valore vero:  1
# Valore predetto: 0 al  52.85 % mentre 1 al  47.15 %. Valore vero:  1
# Valore predetto: 0 al  65.31 % mentre 1 al  34.69 %. Valore vero:  0
# Valore predetto: 0 al  58.58 % mentre 1 al  41.42 %. Valore vero:  0
# Valore predetto: 0 al  53.44 % mentre 1 al  46.56 %. Valore vero:  0
# Valore predetto: 0 al  60.63 % mentre 1 al  39.36 %. Valore vero:  0
# Valore predetto: 0 al  61.6 % mentre 1 al  38.4 %. Valore vero:  0
# Valore predetto: 0 al  64.75 % mentre 1 al  35.25 %. Valore vero:  0
# Valore predetto: 0 al  69.97 % mentre 1 al  30.02 %. Valore vero:  0
# Valore predetto: 0 al  67.54 % mentre 1 al  32.46 %. Valore vero:  0
# Valore predetto: 0 al  66.92 % mentre 1 al  33.08 %. Valore vero:  1
# Valore predetto: 0 al  53.87 % mentre 1 al  46.13 %. Valore vero:  1
# Valore predetto: 0 al  65.75 % mentre 1 al  34.25 %. Valore vero:  0
# Valore predetto: 0 al  61.73 % mentre 1 al  38.26 %. Valore vero:  0
# Valore predetto: 0 al  69.68 % mentre 1 al  30.32 %. Valore vero:  1
# Valore predetto: 0 al  62.15 % mentre 1 al  37.85 %. Valore vero:  1
# Valore predetto: 0 al  64.59 % mentre 1 al  35.41 %. Valore vero:  0
# Valore predetto: 0 al  67.24 % mentre 1 al  32.76 %. Valore vero:  0
# Valore predetto: 0 al  52.6 % mentre 1 al  47.4 %. Valore vero:  1
# Valore predetto: 0 al  51.05 % mentre 1 al  48.94 %. Valore vero:  1
# Valore predetto: 0 al  53.21 % mentre 1 al  46.79 %. Valore vero:  1
# Valore predetto: 0 al  58.12 % mentre 1 al  41.88 %. Valore vero:  0
# Valore predetto: 0 al  65.17 % mentre 1 al  34.83 %. Valore vero:  0
# Valore predetto: 0 al  65.6 % mentre 1 al  34.4 %. Valore vero:  0
# Valore predetto: 0 al  53.49 % mentre 1 al  46.52 %. Valore vero:  0
# Valore predetto: 0 al  66.42 % mentre 1 al  33.58 %. Valore vero:  1
# Valore predetto: 0 al  65.55 % mentre 1 al  34.45 %. Valore vero:  0
# Valore predetto: 0 al  53.53 % mentre 1 al  46.47 %. Valore vero:  1
# Valore predetto: 0 al  69.39 % mentre 1 al  30.61 %. Valore vero:  0
# Valore predetto: 0 al  66.47 % mentre 1 al  33.53 %. Valore vero:  1
# Valore predetto: 0 al  65.96 % mentre 1 al  34.04 %. Valore vero:  1
# Valore predetto: 0 al  66.91 % mentre 1 al  33.09 %. Valore vero:  0
# Valore predetto: 0 al  70.86 % mentre 1 al  29.14 %. Valore vero:  0
# Valore predetto: 0 al  66.06 % mentre 1 al  33.94 %. Valore vero:  0
# Valore predetto: 0 al  64.93 % mentre 1 al  35.07 %. Valore vero:  0
# Valore predetto: 0 al  52.5 % mentre 1 al  47.5 %. Valore vero:  1
# Valore predetto: 0 al  63.42 % mentre 1 al  36.58 %. Valore vero:  1
# Valore predetto: 0 al  67.75 % mentre 1 al  32.25 %. Valore vero:  0
# Valore predetto: 0 al  62.3 % mentre 1 al  37.7 %. Valore vero:  1
# Valore predetto: 0 al  69.14 % mentre 1 al  30.86 %. Valore vero:  1
# Valore predetto: 0 al  52.76 % mentre 1 al  47.24 %. Valore vero:  0
# Valore predetto: 0 al  66.12 % mentre 1 al  33.88 %. Valore vero:  1
# Valore predetto: 0 al  67.83 % mentre 1 al  32.17 %. Valore vero:  0
# Valore predetto: 0 al  63.26 % mentre 1 al  36.74 %. Valore vero:  0
# Valore predetto: 0 al  63.9 % mentre 1 al  36.1 %. Valore vero:  1
# Valore predetto: 0 al  48.83 % mentre 1 al  51.17 %. Valore vero:  0
# Valore predetto: 0 al  52.9 % mentre 1 al  47.1 %. Valore vero:  0
# Valore predetto: 0 al  59.88 % mentre 1 al  40.12 %. Valore vero:  1
# Valore predetto: 0 al  60.27 % mentre 1 al  39.73 %. Valore vero:  1
# Valore predetto: 0 al  70.46 % mentre 1 al  29.54 %. Valore vero:  0
# Valore predetto: 0 al  60.38 % mentre 1 al  39.62 %. Valore vero:  0
# Valore predetto: 0 al  65.32 % mentre 1 al  34.68 %. Valore vero:  0
# Valore predetto: 0 al  68.51 % mentre 1 al  31.5 %. Valore vero:  0
# Valore predetto: 0 al  64.74 % mentre 1 al  35.26 %. Valore vero:  1
# Valore predetto: 0 al  55.58 % mentre 1 al  44.42 %. Valore vero:  0
# Valore predetto: 0 al  65.4 % mentre 1 al  34.6 %. Valore vero:  0
# Valore predetto: 0 al  53.93 % mentre 1 al  46.07 %. Valore vero:  0
# Valore predetto: 0 al  64.44 % mentre 1 al  35.57 %. Valore vero:  1
# Valore predetto: 0 al  68.18 % mentre 1 al  31.82 %. Valore vero:  0
# Valore predetto: 0 al  66.98 % mentre 1 al  33.02 %. Valore vero:  0
# Valore predetto: 0 al  62.67 % mentre 1 al  37.33 %. Valore vero:  0
# Valore predetto: 0 al  59.64 % mentre 1 al  40.36 %. Valore vero:  1
# Valore predetto: 0 al  49.1 % mentre 1 al  50.9 %. Valore vero:  1
# Valore predetto: 0 al  58.22 % mentre 1 al  41.78 %. Valore vero:  1
# Valore predetto: 0 al  62.16 % mentre 1 al  37.84 %. Valore vero:  0
# Valore predetto: 0 al  67.14 % mentre 1 al  32.86 %. Valore vero:  0
# Valore predetto: 0 al  50.47 % mentre 1 al  49.53 %. Valore vero:  0
# Valore predetto: 0 al  67.1 % mentre 1 al  32.9 %. Valore vero:  1
# Valore predetto: 0 al  61.98 % mentre 1 al  38.02 %. Valore vero:  1
# Valore predetto: 0 al  69.06 % mentre 1 al  30.94 %. Valore vero:  0
# Valore predetto: 0 al  52.09 % mentre 1 al  47.91 %. Valore vero:  1
# Valore predetto: 0 al  64.4 % mentre 1 al  35.6 %. Valore vero:  0
# Valore predetto: 0 al  60.35 % mentre 1 al  39.65 %. Valore vero:  1
# Valore predetto: 0 al  55.2 % mentre 1 al  44.8 %. Valore vero:  1
# Valore predetto: 0 al  59.8 % mentre 1 al  40.2 %. Valore vero:  0
# Valore predetto: 0 al  65.68 % mentre 1 al  34.32 %. Valore vero:  1
# Valore predetto: 0 al  62.38 % mentre 1 al  37.62 %. Valore vero:  1
# Valore predetto: 0 al  62.02 % mentre 1 al  37.98 %. Valore vero:  0
# Valore predetto: 0 al  65.06 % mentre 1 al  34.94 %. Valore vero:  0
# Valore predetto: 0 al  68.54 % mentre 1 al  31.46 %. Valore vero:  0
# Valore predetto: 0 al  61.86 % mentre 1 al  38.14 %. Valore vero:  0
# Valore predetto: 0 al  68.77 % mentre 1 al  31.23 %. Valore vero:  1
# Valore predetto: 0 al  54.36 % mentre 1 al  45.64 %. Valore vero:  0
# Valore predetto: 0 al  50.27 % mentre 1 al  49.73 %. Valore vero:  1
# Valore predetto: 0 al  63.46 % mentre 1 al  36.54 %. Valore vero:  1
# Valore predetto: 0 al  67.59 % mentre 1 al  32.41 %. Valore vero:  0
# Valore predetto: 0 al  58.46 % mentre 1 al  41.54 %. Valore vero:  0
# Valore predetto: 0 al  45.7 % mentre 1 al  54.3 %. Valore vero:  0
# Valore predetto: 0 al  54.67 % mentre 1 al  45.33 %. Valore vero:  0
# Valore predetto: 0 al  62.91 % mentre 1 al  37.09 %. Valore vero:  1
# Valore predetto: 0 al  68.94 % mentre 1 al  31.06 %. Valore vero:  0
# Valore predetto: 0 al  66.0 % mentre 1 al  34.0 %. Valore vero:  0
# Valore predetto: 0 al  70.47 % mentre 1 al  29.52 %. Valore vero:  0
# Valore predetto: 0 al  62.52 % mentre 1 al  37.48 %. Valore vero:  1
# Valore predetto: 0 al  63.87 % mentre 1 al  36.13 %. Valore vero:  0
# Valore predetto: 0 al  70.12 % mentre 1 al  29.88 %. Valore vero:  1
# Valore predetto: 0 al  49.25 % mentre 1 al  50.75 %. Valore vero:  1
# Valore predetto: 0 al  67.89 % mentre 1 al  32.11 %. Valore vero:  0
# Valore predetto: 0 al  66.39 % mentre 1 al  33.62 %. Valore vero:  1
# Valore predetto: 0 al  62.28 % mentre 1 al  37.72 %. Valore vero:  1
# Valore predetto: 0 al  54.47 % mentre 1 al  45.52 %. Valore vero:  1
# Valore predetto: 0 al  57.46 % mentre 1 al  42.54 %. Valore vero:  0
# Valore predetto: 0 al  68.76 % mentre 1 al  31.24 %. Valore vero:  0
# Valore predetto: 0 al  63.24 % mentre 1 al  36.76 %. Valore vero:  0
# Valore predetto: 0 al  64.64 % mentre 1 al  35.36 %. Valore vero:  0
# Valore predetto: 0 al  66.7 % mentre 1 al  33.3 %. Valore vero:  0
# Valore predetto: 0 al  68.8 % mentre 1 al  31.2 %. Valore vero:  1
# Valore predetto: 0 al  63.98 % mentre 1 al  36.02 %. Valore vero:  0
# Valore predetto: 0 al  56.02 % mentre 1 al  43.98 %. Valore vero:  0
# Valore predetto: 0 al  66.18 % mentre 1 al  33.83 %. Valore vero:  0
# Valore predetto: 0 al  65.82 % mentre 1 al  34.17 %. Valore vero:  0
# Valore predetto: 0 al  50.33 % mentre 1 al  49.67 %. Valore vero:  1
# Valore predetto: 0 al  68.2 % mentre 1 al  31.8 %. Valore vero:  0
# Valore predetto: 0 al  63.24 % mentre 1 al  36.75 %. Valore vero:  0
# Valore predetto: 0 al  55.74 % mentre 1 al  44.26 %. Valore vero:  1
# Valore predetto: 0 al  63.64 % mentre 1 al  36.36 %. Valore vero:  1
# Valore predetto: 0 al  58.64 % mentre 1 al  41.36 %. Valore vero:  1
# Valore predetto: 0 al  64.69 % mentre 1 al  35.31 %. Valore vero:  0
# Valore predetto: 0 al  55.44 % mentre 1 al  44.56 %. Valore vero:  1
# Valore predetto: 0 al  55.42 % mentre 1 al  44.58 %. Valore vero:  0
# Valore predetto: 0 al  65.0 % mentre 1 al  35.0 %. Valore vero:  0
# Valore predetto: 0 al  64.04 % mentre 1 al  35.96 %. Valore vero:  0
# Valore predetto: 0 al  68.38 % mentre 1 al  31.62 %. Valore vero:  1
# Valore predetto: 0 al  51.54 % mentre 1 al  48.46 %. Valore vero:  0
# Valore predetto: 0 al  62.23 % mentre 1 al  37.77 %. Valore vero:  1
# Valore predetto: 0 al  68.66 % mentre 1 al  31.34 %. Valore vero:  0
# Valore predetto: 0 al  67.66 % mentre 1 al  32.34 %. Valore vero:  1
# Valore predetto: 0 al  62.9 % mentre 1 al  37.1 %. Valore vero:  0
# Valore predetto: 0 al  61.54 % mentre 1 al  38.46 %. Valore vero:  0
# Valore predetto: 0 al  66.95 % mentre 1 al  33.05 %. Valore vero:  0
# Valore predetto: 0 al  66.54 % mentre 1 al  33.46 %. Valore vero:  0
# Valore predetto: 0 al  60.18 % mentre 1 al  39.82 %. Valore vero:  0
# Valore predetto: 0 al  60.06 % mentre 1 al  39.94 %. Valore vero:  0
# Valore predetto: 0 al  56.25 % mentre 1 al  43.75 %. Valore vero:  0
# Valore predetto: 0 al  50.77 % mentre 1 al  49.24 %. Valore vero:  0
# Valore predetto: 0 al  54.06 % mentre 1 al  45.94 %. Valore vero:  0
# Valore predetto: 0 al  51.6 % mentre 1 al  48.4 %. Valore vero:  0
# Valore predetto: 0 al  68.89 % mentre 1 al  31.11 %. Valore vero:  0
# Valore predetto: 0 al  66.76 % mentre 1 al  33.24 %. Valore vero:  0
# Valore predetto: 0 al  67.22 % mentre 1 al  32.78 %. Valore vero:  1
# Valore predetto: 0 al  66.27 % mentre 1 al  33.72 %. Valore vero:  1
# Valore predetto: 0 al  65.16 % mentre 1 al  34.84 %. Valore vero:  0
# Valore predetto: 0 al  64.02 % mentre 1 al  35.98 %. Valore vero:  1
# Valore predetto: 0 al  68.02 % mentre 1 al  31.98 %. Valore vero:  1
# Valore predetto: 0 al  53.58 % mentre 1 al  46.42 %. Valore vero:  1
# Valore predetto: 0 al  54.25 % mentre 1 al  45.75 %. Valore vero:  1
# Valore predetto: 0 al  59.51 % mentre 1 al  40.48 %. Valore vero:  1
# Valore predetto: 0 al  62.11 % mentre 1 al  37.89 %. Valore vero:  0
# Valore predetto: 0 al  64.56 % mentre 1 al  35.44 %. Valore vero:  0
# Valore predetto: 0 al  64.54 % mentre 1 al  35.46 %. Valore vero:  0
# Valore predetto: 0 al  66.45 % mentre 1 al  33.55 %. Valore vero:  0
# Valore predetto: 0 al  58.57 % mentre 1 al  41.43 %. Valore vero:  1
# Valore predetto: 0 al  65.58 % mentre 1 al  34.42 %. Valore vero:  0
# Valore predetto: 0 al  53.71 % mentre 1 al  46.29 %. Valore vero:  0
# Valore predetto: 0 al  65.69 % mentre 1 al  34.31 %. Valore vero:  0
# Valore predetto: 0 al  61.84 % mentre 1 al  38.16 %. Valore vero:  0
# Valore predetto: 0 al  62.76 % mentre 1 al  37.24 %. Valore vero:  1
# Valore predetto: 0 al  53.34 % mentre 1 al  46.66 %. Valore vero:  1
# Valore predetto: 0 al  63.5 % mentre 1 al  36.5 %. Valore vero:  0
# Valore predetto: 0 al  50.15 % mentre 1 al  49.85 %. Valore vero:  0
# Valore predetto: 0 al  56.04 % mentre 1 al  43.96 %. Valore vero:  0
# Valore predetto: 0 al  58.43 % mentre 1 al  41.57 %. Valore vero:  1
# Valore predetto: 0 al  66.97 % mentre 1 al  33.03 %. Valore vero:  0
# Valore predetto: 0 al  64.82 % mentre 1 al  35.17 %. Valore vero:  0
# Valore predetto: 0 al  69.25 % mentre 1 al  30.75 %. Valore vero:  0
# Valore predetto: 0 al  52.72 % mentre 1 al  47.28 %. Valore vero:  1
# Valore predetto: 0 al  68.78 % mentre 1 al  31.22 %. Valore vero:  0
# Valore predetto: 0 al  69.04 % mentre 1 al  30.96 %. Valore vero:  0
# Valore predetto: 0 al  64.61 % mentre 1 al  35.38 %. Valore vero:  0
# Valore predetto: 0 al  63.22 % mentre 1 al  36.78 %. Valore vero:  1
# Valore predetto: 0 al  66.18 % mentre 1 al  33.82 %. Valore vero:  0
# Valore predetto: 0 al  52.4 % mentre 1 al  47.6 %. Valore vero:  0
# Valore predetto: 0 al  66.45 % mentre 1 al  33.55 %. Valore vero:  1
# Valore predetto: 0 al  48.2 % mentre 1 al  51.8 %. Valore vero:  1
# Valore predetto: 0 al  61.44 % mentre 1 al  38.56 %. Valore vero:  1
# Valore predetto: 0 al  68.85 % mentre 1 al  31.15 %. Valore vero:  0
# Valore predetto: 0 al  67.21 % mentre 1 al  32.79 %. Valore vero:  1
# Valore predetto: 0 al  70.45 % mentre 1 al  29.56 %. Valore vero:  0
# Valore predetto: 0 al  55.13 % mentre 1 al  44.87 %. Valore vero:  1
# Valore predetto: 0 al  51.1 % mentre 1 al  48.9 %. Valore vero:  0
# Valore predetto: 0 al  65.92 % mentre 1 al  34.08 %. Valore vero:  0
# Valore predetto: 0 al  66.68 % mentre 1 al  33.32 %. Valore vero:  0
# Valore predetto: 0 al  69.18 % mentre 1 al  30.82 %. Valore vero:  0
# Valore predetto: 0 al  62.32 % mentre 1 al  37.68 %. Valore vero:  0
# Valore predetto: 0 al  65.11 % mentre 1 al  34.89 %. Valore vero:  1
# Valore predetto: 0 al  62.96 % mentre 1 al  37.04 %. Valore vero:  0
# Valore predetto: 0 al  67.14 % mentre 1 al  32.86 %. Valore vero:  0
# Valore predetto: 0 al  69.65 % mentre 1 al  30.35 %. Valore vero:  0
# Valore predetto: 0 al  64.28 % mentre 1 al  35.72 %. Valore vero:  0
# Valore predetto: 0 al  62.62 % mentre 1 al  37.38 %. Valore vero:  0
# Valore predetto: 0 al  67.64 % mentre 1 al  32.36 %. Valore vero:  0
# Valore predetto: 0 al  69.42 % mentre 1 al  30.58 %. Valore vero:  0
# Valore predetto: 0 al  53.09 % mentre 1 al  46.92 %. Valore vero:  0
# Valore predetto: 0 al  63.3 % mentre 1 al  36.7 %. Valore vero:  1
# Valore predetto: 0 al  48.8 % mentre 1 al  51.2 %. Valore vero:  0
# Valore predetto: 0 al  51.43 % mentre 1 al  48.57 %. Valore vero:  0
# Valore predetto: 0 al  52.91 % mentre 1 al  47.09 %. Valore vero:  1
# Valore predetto: 0 al  49.32 % mentre 1 al  50.68 %. Valore vero:  0
# Valore predetto: 0 al  50.84 % mentre 1 al  49.16 %. Valore vero:  1
# Valore predetto: 0 al  64.64 % mentre 1 al  35.36 %. Valore vero:  0
# Valore predetto: 0 al  69.29 % mentre 1 al  30.71 %. Valore vero:  0
# Valore predetto: 0 al  66.42 % mentre 1 al  33.58 %. Valore vero:  1
# Valore predetto: 0 al  52.3 % mentre 1 al  47.7 %. Valore vero:  1
# Valore predetto: 0 al  66.9 % mentre 1 al  33.1 %. Valore vero:  1
# Valore predetto: 0 al  52.66 % mentre 1 al  47.34 %. Valore vero:  0
# Valore predetto: 0 al  53.01 % mentre 1 al  46.99 %. Valore vero:  0
# Valore predetto: 0 al  54.64 % mentre 1 al  45.36 %. Valore vero:  1
# Valore predetto: 0 al  55.3 % mentre 1 al  44.7 %. Valore vero:  0
# Valore predetto: 0 al  52.07 % mentre 1 al  47.93 %. Valore vero:  1
# Valore predetto: 0 al  65.93 % mentre 1 al  34.07 %. Valore vero:  0
# Valore predetto: 0 al  65.48 % mentre 1 al  34.52 %. Valore vero:  1
# Valore predetto: 0 al  54.02 % mentre 1 al  45.98 %. Valore vero:  1
# Valore predetto: 0 al  53.62 % mentre 1 al  46.38 %. Valore vero:  0
# Valore predetto: 0 al  65.2 % mentre 1 al  34.8 %. Valore vero:  0
# Valore predetto: 0 al  52.92 % mentre 1 al  47.08 %. Valore vero:  0
# Valore predetto: 0 al  65.78 % mentre 1 al  34.22 %. Valore vero:  0

# %%
unique, counts = np.unique(pred[:,1], return_counts=True)
print(unique,counts)
# Out:
# [0. 1.] [14487  5513]

# %%
vect = []
for i in range(pred.shape[0]):
  perc = round((pred[i,:]==Y).sum()/272,2)
  vect.append(perc)

# %%
plt.plot(vect)

# %%
y_pred = []
for i in range(pred.shape[1]):
  unique, counts = np.unique(pred[:,i], return_counts=True)
  perc = counts/pred.shape[0]*100
  y_pred.append(np.argmax(perc))

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report

cm= confusion_matrix(Y, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap=plt.cm.Blues)
plt.show()

print('Classification Report')
target_names = ["0","1"]
print(classification_report(Y, y_pred, target_names=target_names))
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            0       0.62      0.95      0.75       168
#            1       0.43      0.06      0.10       104
#
#     accuracy                           0.61       272
#    macro avg       0.52      0.51      0.43       272
# weighted avg       0.55      0.61      0.50       272
